# %% [markdown]
# #Initiate

# %% [markdown]
# ##Requirements

# %%
# install the following libraries 
# !pip install stable-baselines==2.10.2
# !pip install pymoo==0.4.2.2
# !pip install importlib-metadata==4.13.0
# !pip install tensorflow==1.15.2
# !pip install gym==0.21.0

import tensorflow as tf
import gym
import numpy as np
from stable_baselines import DQN
from copy import deepcopy
import math
from gym.spaces import Discrete, Dict, Box
from gym import spaces
from random import seed
import random 
from gym import Env
from datetime import datetime
import sys
import time
import pickle
import stable_baselines
import sklearn
import numpy
from sklearn import tree , svm 
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB , CategoricalNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import accuracy_score
from itertools import product
from sklearn.utils import resample
from sklearn.model_selection import KFold , RepeatedKFold
from sklearn.metrics import f1_score
from sklearn import impute
import statistics
from scipy import stats
from copy import deepcopy
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
from math import ceil
import copy
import sys
from sklearn.metrics import jaccard_score
import time
import multiprocessing
from pymoo.algorithms.nsga2 import calc_crowding_distance
sys.path.append('lib/')
import subprocess
import logging
from sklearn.utils import shuffle
import csv
from csv import reader
import os
# Out:
# c:\Users\Student\Desktop\vs_git\.virtualenvs\venv\lib\site-packages\ale_py\roms\utils.py:90: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
#   for external in metadata.entry_points().get(self.group, []):
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# c:\Users\Student\Desktop\vs_git\.virtualenvs\venv\lib\site-packages\stable_baselines\__init__.py:33: UserWarning: stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation.
#   "stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation."

# %%
# !pip install ipython-autotime

# %load_ext autotime
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ipython-autotime
#   Downloading ipython_autotime-0.3.1-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: ipython in /usr/local/lib/python3.7/dist-packages (from ipython-autotime) (7.9.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (57.4.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (0.2.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (4.8.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (5.1.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (4.4.2)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (2.6.1)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (2.0.10)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.1-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 5.9 MB/s
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.10->ipython->ipython-autotime) (0.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->ipython-autotime) (0.2.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->ipython-autotime) (1.15.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->ipython->ipython-autotime) (0.7.0)
# Installing collected packages: jedi, ipython-autotime
# Successfully installed ipython-autotime-0.3.1 jedi-0.18.1
# time: 790 µs (started: 2022-11-21 00:05:29 +00:00)

# %% [markdown]
# ##RL

# %%
class StoreAndTerminateWrapper(gym.Wrapper):
  ''''
  :param env: (gym.Env) Gym environment that will be wrapped
  :param max_steps: (int) Max number of steps per episode
  '''
  def __init__(self, env):
    # Call the parent constructor, so we can access self.env later
    super(StoreAndTerminateWrapper, self).__init__(env)
    self.max_steps = 200
    # Counter of steps per episode
    self.current_step = 0
    self.mem = []
    self.TotalReward = 0.0 
    self.env = env
    self.first_state = 0
    self.first_obs = 0
    self.prev_obs = 0 
    self.states_list = []
    self.info = {}
  
  def reset(self):
    """
    Reset the environment 
    """
    # Reset the counter
    self.current_step = 0
    obs =self.env.reset()
    self.TotalReward = 0.0
    self.first_obs = obs
    return obs

  def step(self, action):
    """
    In this function we store the initial state as well as the memory of the agent
    :param action: ([float] or int) Action taken by the agent
    :return: (np.ndarray, float, bool, dict) observation, reward, is the episode over?, additional informations
    """
    if self.current_step == 0: #store initial state
      self.prev_obs = self.first_obs
      self.first_state = deepcopy(self.env)
      self.states_list.append(self.first_state)
    self.current_step += 1
    obs, reward, done, info = self.env.step(action)
    self.TotalReward += reward
    self.mem.append(tuple((self.prev_obs,action)))
    self.prev_obs = obs
    if self.current_step >= self.max_steps:
      done = True
      # Update the info dict to signal that the limit was exceeded
    if obs[0]<=-1.2:
      done = True
      reward = -201 - self.TotalReward
      self.TotalReward =-200
      # print("fff",reward)
    if done:
      self.mem.append(tuple(('done',self.TotalReward)))
    self.info['mem'] = self.mem
    self.info['state'] = self.states_list
    # self.mem.append(tuple(obs,action))
    return obs, reward, done, info

  def set_state(self, state):
    """
    :param state: initial state of the episode
    :return: environment is updated and observations is returned
    """
    self.env = deepcopy(state)
    obs = np.array(list(self.env.unwrapped.state))
    self.current_step = 0
    self.TotalReward = 0.0
    self.first_obs = obs
    return obs

def proportional_sampling_whitout_replacement(index , size):
  s=0
  s = sum(np.array(index))
  p = [ind/s for ind in index]
  samples = np.random.choice(index,size=size,replace=False,p=p)
  return samples


def population_sample(episodes , ind,  pop_size , threshold, functional_fault_size, reward_fault_size):
  """
  This function is meant to sample episodes from training after that you need to add test episodes using random_test 
  Set the parameters as you want but be careful the input episodes for this function is the memory of the agent and each step has seperate index 
  this function returns the final steps of the selected function then you need to extract that episodes from the input memore that is called 'episodes'
  use the episodes extract function ... 

  samples n episodes from training n1 functinal faults and n2 reward faults 
  reward faults are episodes with reward bellow the thresthreshold 
  from random test samples M episodes m1 random episode and
  m2 episodes with sudden reward change we dont have a sudden reward change in this example  
  """
  epsilon = 0.1
  index = []
  functional_fault = []
  reward_fault = []
  start_states =[]
  ind  = np.where(np.array(episodes)==('done',))
  index= ind[0]
  print(len(ind[0]),'episodes from training')
  population=[]
  for i in index:
    _,r = episodes[i]
    if abs(episodes[i-1][0][0])<(mtc_wrapped.low[0]+epsilon):
      functional_fault.append(i)
      print('function fault') 
    if r<threshold:
      reward_fault.append(i)
      print('reward fault')
  if len(functional_fault)<functional_fault_size:
    print('functional faults size is' ,len(functional_fault),' and its less than desired number' )
    population += functional_fault
    print('sampling more random episodes instead ...!')
  if len(functional_fault)==functional_fault_size:
    population += functional_fault
  if len(functional_fault)>functional_fault_size:
    # proportianl_sample_whitout_replacement()
    sam1=proportional_sampling_whitout_replacement(functional_fault,functional_fault_size)
    print(population)
    print("ff",len(functional_fault))
    population += sam1
  if len(reward_fault)<reward_fault_size:
    print('reward faults size is' ,len(reward_fault),' and its less than desired number' )
    population += reward_fault
    print('sampling more random episodes instead ...!')
  if len(reward_fault)==reward_fault_size:
    population += reward_fault
  if len(reward_fault)>reward_fault_size:
    #proportional sampling
    sam2 = proportional_sampling_whitout_replacement(reward_fault,reward_fault_size)
    population += list(sam2)
  r_size= pop_size-len(population)
  # random_test(model,env,r_size)
  print("RF",len(reward_fault))
  # population += reward_fault
  return population , r_size


def population_sample_generalaized(episodes ,  pop_size , threshold, functional_fault_size, reward_fault_size):
  """
  This function is meant to sample episodes from training after that you need to add test episodes using random_test 
  Set the parameters as you want but be careful the input episodes for this function is the memory of the agent and each step has seperate index 
  this function returns the final steps of the selected function then you need to extract that episodes from the input memore that is called 'episodes'
  use the episodes extract function ... 

  samples n episodes from training n1 functinal faults and n2 reward faults 
  reward faults are episodes with reward bellow the thresthreshold 
  from random test samples M episodes m1 random episode and
  m2 episodes with sudden reward change we dont have a sudden reward change in this example  
  """
  epsilon = 0.1
  index = []
  functional_fault = []
  reward_fault = []
  start_states =[]
  ind  = np.where(np.array(episodes)==('done',))
  index= ind[0]
  print(len(ind[0]),'episodes from training')
  population=[]
  for i in index:
    _,r = episodes[i]
    if is_functional_fault_last_state(episodes[i-1],episodes[i]):
      functional_fault.append(i)
      # print('function fault') 
    if is_reward_fault_last_state(episodes[i-1],episodes[i]):
      reward_fault.append(i)
      # print('reward fault')
  if len(functional_fault)<functional_fault_size:
    print('functional faults size is' ,len(functional_fault),' and its less than desired number' )
    population += functional_fault
    print('sample more random episodes instead ...!')
  if len(functional_fault)==functional_fault_size:
    population += functional_fault
  if len(functional_fault)>functional_fault_size:
    # proportianl_sample_whitout_replacement()
    sam1=proportional_sampling_whitout_replacement(functional_fault,functional_fault_size)
    print(population)
    print("ff",len(functional_fault))
    print(type(sam1))
    population += list(sam1)
  if len(reward_fault)<reward_fault_size:
    print('reward faults size is' ,len(reward_fault),' and its less than desired number' )
    population += reward_fault
    print('sample more random episodes instead ...!')
  if len(reward_fault)==reward_fault_size:
    population += reward_fault
  if len(reward_fault)>reward_fault_size:
    #proportional sampling
    sam2 = proportional_sampling_whitout_replacement(reward_fault,reward_fault_size)
    population += list(sam2)
  if len(set(population))<len(population):
    print("Duplicated selection.")#this can happen if in an environment both reward and functional faults can happen in one episode. 
  r_size= pop_size-len(population)
  # random_test(model,env,r_size)
  print("RF",len(reward_fault))
  # population += reward_fault
  return population , r_size


def episode_extract(sampled_index, episodes):
  epis = []
  for i in sampled_index:
    l=abs(int(episodes[i][1]))
    slice1 = episodes[(i-l):(i+1)]
    epis.append(slice1)
  return epis




def episode_extract_general(sampled_index, episodes):
  epis = []
  for i in sampled_index:
    # print(episodes[i])
    j = i-1
    while not episodes[j][0] == 'done':
      # print(episodes[j])
      if j==0:
        break
      j-=1
    slice1 = episodes[(j+1):(i+1)]
    epis.append(slice1)
    assert len(slice1)>0, 'Attempt to return Empty episode'
  return epis


def fitness_reward(episode):
  """
  here the reward could be calculated as the lengh of the episode; Since the
  reward of the cartpole is defined based on the number of steps without falling
  last part of the episode contains the signal of ('done',reward)
  """
  return len(episode)-1

def fitness_reward_general(episode):
  """
  here the reward could be calculated as the lengh of the episode; Since the
  reward of the cartpole is defined based on the number of steps without falling
  last part of the episode contains the signal of ('done',reward)
  """
  return episode[-1][1]

def fitness_confidence(episode, model, mode):
  """
  confidence level is define as differences between the highest and
  second highest action probabilities of selecting actions OR
  the ratio between the highest and lowest/second highest action probability
  :param `mode`: r for ration and m for differences 
  :param `model`: is the RL agent 
  :param `episode`: is the episode values or sequence from the rl 
  """
  cl = 0.0
  for i in range(len(episode)):
    if i==(len(episode)-1):
        if episode[i][0]=='done':
            return (cl/episode[i][1])
        else:
            assert False, "last state is not done , reward"
    else:
      prob=model.action_probability(episode[i][0])
      high1=prob.argmax()
      first = prob[high1]
      temp = prob
      temp[high1] = 0.0
      high2= temp.argmax()
      second = prob[high2]
      if mode == 'r':
        cl +=  (first/second)
        #In the next version this will be updated to a normalized ratio to avoid having large values 
      if mode == 'm':
        cl += (first - second) #To_Do: first - second / first +second this one is better 
  print("WARNING nothing returned", episode )

def fitness_confidence_general(episode, model, mode):
  """
  confidence level is define as differences between the highest and
  second highest action probabilities of selecting actions OR
  the ratio between the highest and lowest/second highest action probability
  :param `mode`: r for ration and m for differences 
  :param `model`: is the RL agent 
  :param `episode`: is the episode values or sequence from the rl 
  """
  cl = 0.0
  for i in range(len(episode)):
    if i==(len(episode)-1):
        if episode[i][0]=='done':
            return (cl/(len(episode)-1))
        else:
            assert False, "last state is not done , reward"
    else:
      prob=model.action_probability(episode[i][0])
      high1=prob.argmax()
      first = prob[high1]
      temp = prob
      temp[high1] = 0.0
      high2= temp.argmax()
      second = prob[high2]
      if mode == 'r':
        cl +=  (first/second)
        #In the next version this will be updated to a normalized ratio to avoid having large values 
      if mode == 'm':
        cl += (first - second) #To_Do: first - second / first +second this one is better 
  print("WARNING nothing returned", episode )


def fitness_reward_probability(ml, binary_episode):
  """
  This function returns the third fitness funciton that is ment to guide the search toward
  the episodes with a higher probability of a reward fault and as we have a minimizing 
  optimization funciton in MOSA we neeed to change this functionwe can either go with the
  negation of the probability of the reward fault = 1-probability of the reward fault
  that is equal to the probability of the bein a non-faulty episode
  :param `ml`: RF_FF_1rep for functional fault
  :param `binary episode`: episodes decodeed as having abstract states
  """
  # return -(ml.predict_proba(episode)[0][1])
  return ml.predict_proba(binary_episode)[0][0]

def fitness_functional_probability(ml, binary_episode):
  return ml.predict_proba(binary_episode)[0][0]


def state_abstraction(model,state1,state2,d):
  """
  This function compares to state, if they were in the same abstract class
  function returs 'True' otherwise 'False'
  """
  q_value1 = model.step_model.step([state1])
  q_value2 = model.step_model.step([state2])
  for i in range(len(q_value1[1][0])):
    print(q_value1[1][0][i])
    print(q_value2[1][0][i])
    if ceil(q_value1[1][0][i]/d) == ceil(q_value2[1][0][i]/d):
     continue
    else:
      return False
  return True


def abstract_state(model,state1,d):
  '''
  works only for 2 actions 
  '''
  if type(state1) == str:
    if state1 == 'done':
      return 'end'
  q_value1 = model.step_model.step([state1])
  return( ceil(q_value1[1][0][0]/d), ceil(q_value1[1][0][1]/d))

def abstract_state_general(model,state1,d):
  if type(state1) == str:
    if state1 == 'done':
      return 'end'
  q_values = model.step_model.step([state1])
  return tuple([ceil(q_value/d) for q_value in q_values[1][0]])


#report function to check the performance metrics of the model
def report(model2,x_train, y_train,x_test, y_test):
  print("********************** reporting the result of the model **************************")
  print('The score for train data is {0}'.format(model2.score(x_train,y_train)))
  print('The score for test data is {0}'.format(model2.score(x_test,y_test)))


  predictions_train = model2.predict(x_train)
  predictions_test = model2.predict(x_test)

  print("\n\n--------------------------------------recall---------------------------------")

  print('the test recall for the class yes is {0}'.format(metrics.recall_score(y_test,predictions_test, pos_label=1)))
  print('the test recall for the class no is {0}'.format(metrics.recall_score(y_test,predictions_test, pos_label=0)))

  print('the training recall for the class yes is {0}'.format(metrics.recall_score(y_train,predictions_train, pos_label=1)))
  print('the training recall for the class no is {0}'.format(metrics.recall_score(y_train,predictions_train, pos_label=0)))


  print("\n\n--------------------------------------precision------------------------------")


  print('the test precision for the class yes is {0}'.format(metrics.precision_score(y_test,predictions_test, pos_label=1)))
  print('the test precision for the class no is {0}'.format(metrics.precision_score(y_test,predictions_test, pos_label=0)))

  print('the training precision for the class yes is {0}'.format(metrics.precision_score(y_train,predictions_train, pos_label=1)))
  print('the training precision for the class no is {0}'.format(metrics.precision_score(y_train,predictions_train, pos_label=0)))

  print("\n\n")
  print(classification_report(y_test, predictions_test, target_names=['NO ','yes']))

  tn, fp, fn, tp = confusion_matrix(y_test, predictions_test).ravel()
  specificity = tn / (tn+fp)
  print("\n\nspecifity :",specificity)
  print("\n\n--------------------------------------confusion----------------------------")
  CM = metrics.confusion_matrix(y_test, predictions_test)
  print("The confusion Matrix:")
  print(CM)
  print('the accuracy score in {0}\n\n'.format(accuracy_score(y_test, predictions_test)))
  print("********************** plotting the confusion matrix & ROC curve **************************")
  plot_confusion_matrix(model2, x_test, y_test)
  metrics.plot_roc_curve(model2, x_test, y_test) 
  plt.show()

#dump

def dump_p(what, name):
  with open(f'/content/drive/MyDrive/MC/{name}.pickle', 'wb') as file:
      pickle.dump(what, file)


# write function for load

def load_p(name):
  with open(f'/content/drive/MyDrive/MC/{name}.pickle', 'rb') as file2:
    to_what = pickle.load(file2)
  return to_what


def random_test_1(model, env, Num):
  obs=env.reset()
  counter = 1
  episode_reward = 0.0
  for i in range(Num):
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, done, info = env.step(action)
    # env.render()
    episode_reward += reward
    if done:
      counter += 1
      end = i
      print("Reward:", episode_reward, "final state", info['mem'][-2][0])
      episode_reward = 0.0
      obs = env.reset()
  iter = deepcopy(counter)
  u=1
  while iter>1:
    if info['mem'][-u][0]=='done':
      lastpoint = -u
      iter -= 1
    u+=1
  fin =Num - end
  start = -Num -counter
  randomtest = info['mem'][lastpoint:-fin]
  ran_state = info['state'][(-counter+1):-1]
  return randomtest , ran_state


def fix_training(training_episodes,training_states):
  buffer =[] 
  episodes_set = []
  j=0
  for i in range(len(training_episodes)):
    if training_episodes[i][0] == 'done':
      if i == 0:
        continue
      buffer.append(training_episodes[i])
      episodes_set.append(buffer)
      buffer=[]
    else:
      buffer.append(training_episodes[i])
  if len(episodes_set)!=len(training_states):
    del training_states[-1]
  if len(episodes_set)!=len(training_states):
    # assert False, 'problem in starting states'
    print('problem in starting states')
  return episodes_set , training_states

def fix_testing(testing_episodes,testing_states,Env2):
  buffer =[] 
  episodes_set = []
  j=0
  for i in range(len(testing_episodes)):
    if testing_episodes[i][0] == 'done':
      if i == 0:
        continue
      buffer.append(testing_episodes[i])
      episodes_set.append(buffer)
      buffer=[]
    else:
      buffer.append(testing_episodes[i])
      # np.array(mtc_wrapped.set_state(qq[0]),dtype="float32")
  if not (episodes_set[0][0][0]==np.array(Env2.set_state(testing_states[0]),dtype="float32")).all():
    del testing_states[0]
  if not (episodes_set[0][0][0]==np.array(Env2.set_state(testing_states[0]),dtype="float32")).all():
    assert False, 'problem in starting states'
  if len(episodes_set)!=len(testing_states):
    del testing_states[-1]
  if len(episodes_set)!=len(testing_states):
    assert False, 'problem in data prepration'
  return episodes_set , testing_states

# %% [markdown]
# ##ML

# %%
def Abstract_classes(ep,abstraction_d,model):
  d=abstraction_d
  abs_states1=[]
  for episode in ep:
    for state,action in episode:
      abs_st = abstract_state_general(model,state,d)
      if abs_st == 'end':
        continue
      abs_states1.append(abs_st)
  unique1=list(set(abs_states1))
  uni1 = np.array(unique1)
  a=len(abs_states1)
  b=len(set(abs_states1))
  print("abstract states:",b)
  print("Concrete states",a)
  print("ratio",b/a)
  return unique1,uni1


def ML_first_representation(Abs_d,epsilon_functional_fault_boarder,Reward_fault_boarder,uni1,model,ep,unique1):
  """
  TO-DO : fix epsilon and threshold
  """
  d = Abs_d
  # epsilon = 0.05
  epsilon = epsilon_functional_fault_boarder
  data1_x_b=[]
  data1_y_b= [] 
  data1_y_f_b = []
  functional_fault = False
  reward_fault_threshold =  Reward_fault_boarder

  for episode in ep:
    record = np.zeros(len(uni1))
    for state, action in episode:
      ab = abstract_state(model,state,d)
      if ab == 'end':
        print(action)
        if functional_fault:
          data1_y_f_b.append(1)
        else:
          data1_y_f_b.append(0)
        if action >= reward_fault_threshold:
          data1_y_b.append(0)
        else:
          data1_y_b.append(1)
        functional_fault=False
        continue
      if state[0] < (-1.2+epsilon) :
        # print("ff found")
        functional_fault = True
        print(state[0])
      ind = unique1.index(ab)
      # if len(w[0])>1:
        # print('error len is greater than 1')
      record[ind] = 1
      # if you want the frequency go with the next line 
      # record[ind] += 1
    data1_x_b.append(record)

  return data1_x_b, data1_y_b, data1_y_f_b

def ML_first_representation_func_based(Abs_d,functional_func,reward_func,model,input_episodes,unique1):
  """
  TO-DO : fix epsilon and threshold
  """
  d = Abs_d
  data1_x_b=[]
  data1_y_b= [] 
  data1_y_f_b = []
  for i, episode in enumerate(input_episodes):
    record = np.zeros(len(unique1))
    temp_flag = False
    for state, action in episode:
      ab = abstract_state_general(model,state,d)
      if ab == 'end':
        assert not temp_flag, f'Episode data problem, two terminations in one episode. Episode number{i}'
        temp_flag = True
        # print(action)
        # print(functional_func(episode))
        if functional_func(episode):
          data1_y_f_b.append(1)
        else:
          data1_y_f_b.append(0)
        if reward_func(episode):
          data1_y_b.append(1)
        else:
          data1_y_b.append(0)
        # print("end\n\n\n")
        # print(len(data1_y_b),"len(input_episodes)",len(input_episodes))
        continue
        # print(state[0])
      ind = unique1.index(ab)
      record[ind] = 1
      # print(state, action)
      assert len(data1_y_b)<len(input_episodes), "assert"
      # if you want the frequency go with the next line 
      # record[ind] += 1
    data1_x_b.append(record)

  return data1_x_b, data1_y_b, data1_y_f_b

# %% [markdown]
# ##Genetic

# %%
def translator(episode,model, d, unique5):
  """
  thid function takes the concrete episodes and returns the encoded episodes 
  based on the presence and absence of the individuals  
  :param 'episode': input episode
  :param 'model': RL model
  :param 'd': abstraction level = 1
  :param 'unique5': abstract classes 
  :return: encoded episodse based on the presence and absence

  """
  d=d
  record = np.zeros(len(unique5))
  for state, action in episode:
    ab = abstract_state_general(model,state,d)
    if ab == 'end':
      continue
    if ab in unique5:
      ind = unique5.index(ab)
    record[ind] = 1
  return [record]

def transform(state):
  position = state[0]
  noise = np.random.uniform(low=0.95, high=1.05)
  new_position= position * noise 
  new_state =deepcopy(state)
  new_state[0] = new_position 
  return new_state


def mutation_improved(population,model,env,objective_uncovered):
  """
  This is the final mutation function 
  It takes the population as input and returns the mutated individual
  :param 'population': Population that we want to mutate 
  :param 'model': RL model
  :param 'env': RL environment
  :param 'objective_uncovered: uncovered ubjectives for tournament selection
  :return: mutated candidate (we re-rexecute the episode from the mutation part)
  To-do:
  move deepcopy to the cadidate class methods .set info 
  """
  parent = tournament_selection(population, 10, objective_uncovered)  # tournament selection
  parent1 = deepcopy(parent.get_candidate_values())
  if len(parent1) < 3:
     assert False , "parent in mutation is shorter than 3"
  Mutpoint = random.randint(3,(len(parent1)-3))
  new_state = transform(parent1[Mutpoint][0])
  action = model.predict(new_state)
  if action[0]!= int(parent1[Mutpoint][1]):
    print('Mutation lured the agent ... ')
  new_parent = parent1[:Mutpoint]
  new_parent.append([new_state,'Mut'])
  new_cand =Candidate(new_parent)
  new_cand.set_start_state(parent.get_start_state())

  re_executed_epis = re_execute(model,env,new_cand)
  
  re_executed_cand = Candidate(re_executed_epis)
  re_executed_cand.set_start_state(new_cand.get_start_state())
  re_executed_cand.set_info(deepcopy(parent.get_info()))
  re_executed_cand.set_info(["mutation is done! ", "mutpoint was:",Mutpoint])

  
  return re_executed_cand

def mutation_improved_p(parent,model,env,m_rate):
  """
  This is the final mutation function with input of a parent considering internal m_rate
  Here we give the parent to themutation funcion based on the given mutation 
  rate of m_rate, we may mutate the episodes. 
  :param 'parent' : individual that we want to mutate
  :param 'model': RL model
  :param 'env': RL environment
  :param 'm_rate': mutation : recommended value is 1/len(parent)
  :return : mutated individual
  To-do:
  move deepcopy to the cadidate .set info 
  """
  # parent = tournament_selection(population, 10, objective_uncovered)  # tournament selection
  global MUTATION_NUMBER
  chance = random.uniform(0, 1)
  if chance> m_rate:
    return parent
  else:
    # print(112)
    parent1 = deepcopy(parent.get_candidate_values())
    if len(parent1) < 3:
      assert False , "parent in mutation is shorter than 3"
    Mutpoint = random.randint(3,(len(parent1)-3))
    new_state = transform(parent1[Mutpoint][0])
    action = model.predict(new_state,deterministic=True)
    if action[0]!= int(parent1[Mutpoint][1]):
      print('Mutation lured the agent ... ')
    new_parent = parent1[:Mutpoint]
    new_parent.append([new_state,'Mut'])
    new_cand =Candidate(new_parent)
    new_cand.set_start_state(parent.get_start_state())
    re_executed_epis = re_execute(model,env,new_cand)
    n_reward = find_reward(re_executed_epis)
    re_executed_epis[-1] = ('done',n_reward)
    re_executed_cand = Candidate(re_executed_epis)
    re_executed_cand.set_start_state(new_cand.get_start_state())
    MUTATION_NUMBER+=1
    return re_executed_cand




def Crossover_improved_v2(population,model,d,objective_uncovered):
  """
  This is the crossover function that we are using 
  It takes the population as input and returns the mutated individual
  :param 'population': Population. we select a parent based on the tournament
   selection and then select the mutation point and then search for the matching point. 
  :param 'model': RL model
  :param 'env': RL environment
  :param 'objective_uncovered: uncovered ubjectives for tournament selection
  :return: mutated candidate (we re-rexecute the episode from the mutation part)
  To-do:
  finding matching episode could be improved bu storing a mapping between concrete states and  
  """
  found_match = False 
  while not (found_match):
    parent = tournament_selection(population, 10, objective_uncovered)  # tournament selection
    parent1 = deepcopy(parent.get_candidate_values())
    parent1_start_point = deepcopy(parent.get_start_state())
    if len(parent1)<4:
      assert False, 'input of crossover is shorter than expected '
    matches_list = []
    crosspoint = random.randint(1,(len(parent1)-3))
    abs_class = list(abstract_state_general(model,parent1[crosspoint][0],d))
    for i in range(50):
      indx = random.randint(0, len(population) - 1)
      random_candidate = deepcopy(population[indx])
      random_cand_data = random_candidate.get_candidate_values()
      random_cand_start_point = random_candidate.get_start_state()
      for st_index in range(1,len(random_cand_data)-3):
        random_ab = list(abstract_state_general(model,random_cand_data[st_index][0],d))
        if random_ab == abs_class:
          matches_list.append(st_index)
          found_match = True
      if found_match:
        break 
  # print('Crossover. attemp',i)
  index_match_in_matchlist = random.randint(0, len(matches_list) - 1)
  matchpoint = matches_list[index_match_in_matchlist]
  match_candidate =  deepcopy(random_candidate)
  match = deepcopy(random_cand_data)
  match_start = deepcopy(random_cand_start_point)
  offspring1 = deepcopy(parent1[:crosspoint])
  offspring1 += deepcopy(match[matchpoint:])
  new_reward1  = find_reward(offspring1)

  offspring1[-1] = ('done',new_reward1)

  candid1 = Candidate(offspring1)
  candid1.set_start_state(parent1_start_point)

  offspring2 = deepcopy(match[:matchpoint])
  offspring2 += deepcopy(parent1[crosspoint:])

  new_reward2  = find_reward(offspring2)
  offspring2[-1] = ('done',new_reward2)
  candid2 = Candidate(offspring2)
  candid2.set_start_state(match_start)


  if len(offspring1)<4:
    print(offspring1)
    assert False, 'created offspring 1 in crossover is shorter than expected '

  if len(offspring2)<4:
    print(offspring2)
    assert False, 'created offspring 2 in crossover is shorter than expected '

  return candid1, candid2

def find_reward(episode):
  if len(episode)>200:
    return -200
  if len(episode)<=200:
    if is_functional_fault_last_state(episode[-2],episode[-1]):
      return -200
    else:
      return -(len(episode)-1)

def Crossover_improved_v2_random(population,model,d,objective_uncovered):
  found_match = False 
  while not found_match:
    i = random.randint(0, len(population))
    parent1 = deepcopy(population[i].get_candidate_values())
    parent1_start_point = deepcopy(population[i].get_start_state())
    matches_list = []
    crosspoint = random.randint(1,(len(parent1)-3))
    abs_class = list(abstract_state(model,parent1[crosspoint][0],d))
    attemp = 0
    for i in range(700):
      attemp +=1
      indx = random.randint(0, len(population) - 1)
      random_candidate = deepcopy(population[indx])
      random_cand_data = random_candidate.get_candidate_values()
      random_cand_start_point = random_candidate.get_start_state()
      for st_index in range(1,len(random_cand_data)-3):
        random_ab = list(abstract_state(model,random_cand_data[st_index][0],d))
        if random_ab == abs_class:
          matches_list.append(st_index)
          found_match = True
      if found_match:
        break 
  print("match found in --- attemps",attemp)
  index_match_in_matchlist = random.randint(0, len(matches_list) - 1)
  matchpoint = matches_list[index_match_in_matchlist]
  match_candidate = random_candidate
  match = random_cand_data
  match_start = deepcopy(random_cand_start_point)
  offspring1 = deepcopy(parent1[:crosspoint])
  offspring1 += deepcopy(match[matchpoint:])
  offspring1[-1] = ['done',(len(offspring1)-1)]
  candid1 = Candidate(offspring1)
  candid1.set_start_state(parent1_start_point)

  offspring2 = deepcopy(match[:matchpoint])
  offspring2 += deepcopy(parent1[crosspoint:])
  offspring2[-1] = ['done',(len(offspring2)-1)]
  candid2 = Candidate(offspring2)
  candid2.set_start_state(match_start)
  return candid1, candid2

#updated for Mountain car
def re_execute(model,env,candidate):
  obs =env.reset()
  obs =env.set_state(deepcopy(candidate.get_start_state()))
  episode = candidate.get_candidate_values()
  steps_to_mut_point = len(episode)
  episode_reward = 0.0
  done= False 
  counter = 0 
  for i in range(steps_to_mut_point):
    action, _ = model.predict(obs, deterministic=True)
    action_selected = episode[i][1]
    if action_selected == 'Mut':
      # print(episode[i])
      # print(episode[i][0])
      action_selected, _ = model.predict(episode[i][0], deterministic=True)
      # print("ddd",i,"eee",steps_to_mut_point)
      # print(action_selected)
      # break
    obs, reward, done, info = env.step(int(action_selected)) # its very important to select the action here it means that we may 
    counter+=1
    #follow the previous path until the mutation point or we follow the route that the trained agent wants to follow forcing vs following 
    episode_reward += reward
    # print("counter",counter)
    if done:
      break 
  for j in range(200):
    if done:
      break
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, done, info = env.step(action) 
    counter+=1
    episode_reward += reward
  assert done
  if episode_reward>201:
    assert False 
  return env.info['mem'][-((counter)+1):]


def re_execution_improved(model,env,candidate):
  differences=[]
  episode_limit = 200 
  env.reset()
  obs =env.set_state(candidate.get_start_state()) 
  episode = candidate.get_candidate_values()
  # steps_to_mut_point = len(episode)
  episode_reward = 0.0
  for i in range(episode_limit):
    action, _ = model.predict(obs, deterministic=True)
    action_selected = episode[i][1]
    if  episode[i][0]=='done':
      continue
    if i >=len(episode):
      action, _ = model.predict(obs, deterministic=True)
      obs, reward, done, info = env.step(int(action)) 
      continue
    if action != int(action_selected):
      prob=model.action_probability(episode[i][0])
      differences.append([i , prob])
    obs, reward, done, info = env.step(int(action_selected))
    # env.render()
    # env.reset = state1
    episode_reward += reward
    if done:
      # assert not done
      break 
  assert done , "not finished in 2oo steps "
  return differences


def re_execution_improved_v2(model,env,candidate):
  differences=[]
  episode_limit = 200 
  env.reset()
  obs =env.set_state(candidate.get_start_state()) 
  episode = candidate.get_candidate_values()
  episode_reward = 0.0
  for i in range(episode_limit):
    if i >=(len(episode)-1):
      action, _ = model.predict(obs, deterministic=True)
      obs, reward, done, info = env.step(int(action)) 
      if done:
      # assert not done
        print("Reward:", episode_reward)
        # break
        return differences 
      continue
    action, _ = model.predict(obs, deterministic=True)
    if  episode[i][0]=='done':
      print("first scenario, episode finished correctly")
      # continue
    print(len(episode),i)
    action_selected = episode[i][1]
    if action != int(action_selected):
      prob=model.action_probability(episode[i][0])
      differences.append([i , prob])
    obs, reward, done, info = env.step(int(action_selected)) 
    # env.render()
    # env.reset = state1
    episode_reward += reward
    if done:
      # assert not done
      break 
  assert done , "not finished in 2oo steps "
  return differences

# %%
#changed
import numpy as np
class Candidate:
    def __init__(self, candidates_vals):
        if isinstance(candidates_vals, (np.ndarray, np.generic)):
            self.candidate_values = candidates_vals.tolist()
        else:
            self.candidate_values = candidates_vals
        self.objective_values = []
        self.objectives_covered = []
        self.crowding_distance = 0
        self.uncertainity = []
        self.start_state = 0
        self.information = []
        self.mutation = False

    def get_candidate_values(self):
        return self.candidate_values

    def get_uncertainity_value(self, indx):
        return self.uncertainity[indx]
    def get_uncertainity_values(self):
        return self.uncertainity
    def set_uncertainity_values(self,uncertain):
        self.uncertainity = uncertain
    def set_candidate_values(self, cand):
        self.candidate_values = cand
    def set_candidate_values_at_index(self, indx,val):
        self.candidate_values[indx] = val

    def get_objective_values(self):
        return self.objective_values

    def get_objective_value(self, indx):
        return self.objective_values[indx]

    def set_objective_values(self, obj_vals):
        self.objective_values = obj_vals

    def add_objectives_covered(self, obj_covered):
        if obj_covered not in self.objectives_covered:
            self.objectives_covered.append(obj_covered)

    def get_covered_objectives(self):
        return self.objectives_covered

    def set_crowding_distance(self, cd):
        self.crowding_distance = cd

    def get_crowding_distance(self):
        return self.crowding_distance

    def exists_in_satisfied(self, indx):
        for ind in self.objectives_covered:
            if ind == indx:
                return True
        return False

    def is_objective_covered(self, obj_to_check):
        for obj in self.objectives_covered:
            if obj == obj_to_check:
                return True
        return False
    def set_start_state(self,start_point):
      self.start_state = deepcopy(start_point)

    def get_start_state(self):
      return self.start_state

    def set_info(self, new_information):
      self.information.append(new_information)
      
    def get_info(self):
      return self.information

    def mutated(self):
      self.mutation = True

# %%
def mutation_number_update(file_address,Mut_Num_to_add,iteration):
  if iteration == 0:
    with open(file_address, 'wb') as file:
      pickle.dump(Mut_Num_to_add, file)
    return
  with open(file_address, 'rb') as file2:
    Mut_num = pickle.load(file2)
  print(Mut_num)
  if type(Mut_num) == list:
    print('list')
    buffer = Mut_num
    buffer.append(Mut_Num_to_add)
    print(buffer)
  else:
    print('int')
    buffer =[] 
    buffer.append(Mut_num)
    buffer.append(Mut_Num_to_add)
    print(buffer)
  with open(file_address, 'wb') as file:
    pickle.dump(buffer, file)

# %% [markdown]
# ##MOSA

# %%
scaler = preprocessing.StandardScaler()



# domination relation method, same as MOSA 
def dominates(value_from_pop, value_from_archive, objective_uncovered):
    dominates_f1 = False
    dominates_f2 = False
    for each_objective in objective_uncovered:
        f1 = value_from_pop[each_objective]
        f2 = value_from_archive[each_objective]
        if f1 < f2:
            dominates_f1 = True
        if f2 < f1:
            dominates_f2 = True
        if dominates_f1 and dominates_f2:
            break
    if dominates_f1 == dominates_f2:
        return False
    elif dominates_f1:
        return True
    return False




# calculating the fitness value function

def evaulate_population(func, pop , parameters):
    for candidate in pop:
      if isinstance(candidate, Candidate):
        # print(candidate.get_candidate_values())
        result = func(candidate.get_candidate_values())
        candidate.set_objective_values(result)
        print(candidate.get_objective_values())

def evaulate_population_with_archive(func, pop, already_executed):
    to_ret = []
    for candidate in pop:
        if isinstance(candidate, Candidate):
            if candidate.get_candidate_values() in already_executed:
                continue

            result = func(candidate.get_candidate_values())
            candidate.set_objective_values(result)
            already_executed.append(candidate.get_candidate_values())
            to_ret.append(candidate)
    return to_ret

def exists_in_archive(archive, index):
    for candidate in archive:
        if candidate.exists_in_satisfied(index):
            return True
    return False


# searching archive
def get_from_archive(obj_index, archive):
    for candIndx in range(len(archive)):
        candidate = archive[candIndx]
        if candidate.exists_in_satisfied(obj_index):
            return candidate, candIndx
    return None


# updating archive with adding the number of objective it satisfies, Same as Mosa paper
def update_archive(pop, objective_uncovered, archive, no_of_Objectives, threshold_criteria):
    for objective_index in range(no_of_Objectives):
        for pop_index in range(len(pop)):
            objective_values = pop[pop_index].get_objective_values()
            # if not objective_values[objective_index] or not threshold_criteria[objective_index]:
            if objective_values[objective_index] <= threshold_criteria[objective_index]:
                if exists_in_archive(archive, objective_index):
                    archive_value, cand_indx = get_from_archive(objective_index, archive)
                    obj_archive_values = archive_value.get_objective_values()
                    if obj_archive_values[objective_index] > objective_values[objective_index]:
                        value_to_add = pop[pop_index]
                        value_to_add.add_objectives_covered(objective_index)
                        # archive.append(value_to_add)
                        archive[cand_indx] = value_to_add
                        if objective_index in objective_uncovered:
                            objective_uncovered.remove(objective_index)
                        # archive.remove(archive_value)
                else:
                    value_to_add = pop[pop_index]
                    value_to_add.add_objectives_covered(objective_index)
                    archive.append(value_to_add)
                    if objective_index in objective_uncovered:
                        objective_uncovered.remove(objective_index)


# method to get the most dominating one
def select_best(tournament_candidates, objective_uncovered):
    best = tournament_candidates[0]  # in case none is dominating other
    for i in range(len(tournament_candidates)):
        candidate1 = tournament_candidates[i]
        for j in range(len(tournament_candidates)):
            candidate2 = tournament_candidates[j]
            if (dominates(candidate1.get_objective_values(), candidate2.get_objective_values(), objective_uncovered)):
                best = candidate1
    return best


def tournament_selection_improved(pop, size, objective_uncovered):
    tournament_candidates = []
    for i in range(size):
        indx = random.randint(0, len(pop) - 1)
        random_candidate = pop[indx]
        tournament_candidates.append(random_candidate)

    best = select_best(tournament_candidates, objective_uncovered)
    return best;


def tournament_selection(pop, size, objective_uncovered):
    tournament_candidates = []
    for i in range(size):
        indx = random.randint(0, len(pop) - 1)
        random_candidate = pop[indx]
        tournament_candidates.append(random_candidate)

    best = select_best(tournament_candidates, objective_uncovered)
    return best;




def generate_offspring_improved(population,model,env,d,objective_uncovered):
    population_to_return = []
    probability_C = 0.75
    probability_M = 0.3
    size = len(population)
    while (len(population_to_return) < size):
      probability_crossover = random.uniform(0, 1)
      if probability_crossover <= probability_C:  # 75% probability
        off1, off2 = Crossover_improved_v2(population,model,1,objective_uncovered)
        population_to_return.append(off1)
        population_to_return.append(off2)
      probability_mutation = random.uniform(0, 1)
      if probability_mutation <= probability_M:  # 30% probability this in for test purposes 
        off3 = mutation_improved(population, model,env,objective_uncovered)
        population_to_return.append(off3)
    return population_to_return






def generate_offspring_improved_v2(population,model,env,d,objective_uncovered):
    
    population_to_return = []
    probability_C = 0.75
    probability_M = 0.01
    size = len(population)
    while (len(population_to_return) < size):
      probability_crossover = random.uniform(0, 1)
      if probability_crossover <= probability_C:  # 75% probability
        parent1, parent2 = Crossover_improved_v2(population,model,d,objective_uncovered)
        parent1 = mutation_improved_p(parent1, model,env, (1 / len(parent1.get_candidate_values())))
        parent2 = mutation_improved_p(parent2, model,env, (1 / len(parent2.get_candidate_values())))
        population_to_return.append(parent1)
        population_to_return.append(parent2)

      if probability_crossover > probability_C:
        parent = tournament_selection(population, 10, objective_uncovered) #we may add a very small number of duplicated individulas but its not important as we are removing them in the final executions
        population_to_return.append(mutation_improved_p(parent, model,env,(1 / len(parent.get_candidate_values())))) 
      

    return population_to_return

def save_all_data(pop,no_of_Objectives,threshold_criteria, stored_data):
  '''
  This function will save all individulas with objective lower than treshhold 

  '''
  threshold_criteria_to_add_to_archive = [70, 0.06, 0.05, 0.05] 
  # be careful here ypu can set the satisfiing objectives that based on them you want to store the data  
  for individual in pop:
    individual_objective = individual.get_objective_values()
    for i in range(no_of_Objectives):
      if individual_objective[i]<threshold_criteria_to_add_to_archive[i]:
        # if individual not in stored_data:
        #   ind_ = deepcopy(individual)
        #   stored_data.append(ind_)
        # individual_objective_values = individual.get_objective_values()
        found = False
        for j in range(len(stored_data)):
          if individual_objective == stored_data[j].get_objective_values():
            found = True
            break
        if not found:
          ind_ = deepcopy(individual)
          stored_data.append(ind_)
  # return stored_data

def save_all_data2(pop, stored_data):
  '''
  This function will save all individulas in generations 
  you need to remove redundant data (based on fitness and ...)

  '''
  stored_data.append(list(pop))


def Build_Archive(pop,no_of_Objectives,threshold_criteria, stored_data, initial_population):
  '''
  If you are using the Archive of all generated episodes, this function
  removes the duplicated results and builds the Archive.
  :param 'pop': current generation
  :param 'no_of_Objectives': number of objectives
  :param 'threshold_criteria': threshold criteria (we are intrested in episodes that have fitness below these threshold values)
  :param 'stored_data': Archive of final episodes (return)
  :param 'initial_population': initial population. we are not considering these episodes in our archive for the second senario you need to add the number of faults, (implementation in RQ3)
  '''
  threshold_criteria_to_add_to_archive = threshold_criteria
# be careful as we can have different values for criterias here to add episodes to archive and for GA stopping criteria 
  for individual in pop:
    individual_objective = individual.get_objective_values()
    for i in range(no_of_Objectives):
      if individual_objective[i]<threshold_criteria_to_add_to_archive[i]:
        found = False
        for j in range(len(stored_data)):
          if individual_objective == stored_data[j].get_objective_values():
            found = True
            break
        for k in range(len(initial_population)):
          if individual_objective == initial_population[k].get_objective_values():
            found = True
            break
        if not found:
          ind_ = deepcopy(individual)
          stored_data.append(ind_)

# %% [markdown]
# ###Sorting and RUN search

# %%
# finding best candidates and assigning to each front
def fast_dominating_sort(R_T, objective_uncovered):
    to_return = []
    front = []
    count = 0
    while len(R_T) > 1:
        count = 0
        for outer_loop in range(len(R_T)):
            best = R_T[outer_loop]
            add = True
            for inner_loop in range(len(R_T)):
                against = R_T[inner_loop]
                if best == against:
                    continue
                if (dominates(best.get_objective_values(), against.get_objective_values(), objective_uncovered)):
                    continue
                else:
                    add = False
                    break

            if add == True:
                if best not in front:
                    front.append(best)

                count = count + 1

        if len(front) > 0:
            to_return.append(front)
            for i in range(len(front)):
                R_T.remove(front[i])
                front = []

        if (len(to_return) == 0) or (count == 0):  # to check if no one dominates no one
            to_return.append(R_T)
            break

    return to_return


# sorting based on crowding distance
def sort_based_on_crowding_distance(e):
    values = e.get_crowding_distance()
    return values


def sort_based_on(e):
    values = e.get_objective_values()
    return values[0]


# sorting based on first objective value
def sort_worse(pop):
    pop.sort(key=sort_based_on, reverse=True)
    return pop
# preference sort, same as algorithm
def preference_sort(R_T, size, objective_uncovered):
    to_return = []
    for objective_index in objective_uncovered:
        min = 100
        best = R_T[0]
        for index in range(len(R_T)):
            objective_values = R_T[index].get_objective_values()
            if objective_values[objective_index] < min:
                min = objective_values[objective_index]
                best = R_T[index]
        to_return.append(best)
        R_T.remove(best)
    if len(R_T)>0:
        E = fast_dominating_sort(R_T, objective_uncovered)
        for i in range(len(E)):
            to_return.append(E[i])
    return to_return


# converting to numpy array (Required by library)
def get_array_for_crowding_distance(sorted_front):
    list = []
    for value in sorted_front:
        objective_values = value.get_objective_values()

        np_array = numpy.array(objective_values)
        list.append(np_array)

    np_list = np.array(list)
    cd = calc_crowding_distance(np_list)
    return cd
# method to assign each candidate its crownding distance

def assign_crowding_distance_to_each_value(sorted_front, crowding_distance):
    for candidate_index in range(len(sorted_front)):
        objective_values = sorted_front[candidate_index]
        objective_values.set_crowding_distance(crowding_distance[candidate_index])

def run_search(func, initial_population, no_of_Objectives, criteria,archive,logger,start,time_budget,size,d,env, parameters , second_archive,gens):
    global MUTATION_NUMBER
    MUTATION_NUMBER=0
    threshold_criteria = criteria 
    objective_uncovered = []
    print("initial population ",type(initial_population),len(initial_population))

    for obj in range(no_of_Objectives):
        objective_uncovered.append(obj)  # initializing number of uncovered objective

    random_population = initial_population 

    P_T = copy.copy(random_population)
    evaulate_population(func, random_population ,parameters)  # evaluating whole generation and storing results propabibly its with candidates

    # print(random_population[0].get_objective_values())
    update_archive(random_population, objective_uncovered, archive, no_of_Objectives,threshold_criteria)  # updating archive 
    # save initial population
    save_all_data2(random_population,gens)
    iteration = 0
    #limit of number of generations 
    while iteration <10:
        iteration = iteration + 1  # iteration count
        #To-DO: limit by the time budget instead of the generation number
        for arc in archive:
            logger.info("***ARCHIVE***")
            logger.info("\nValues: " + str(
                arc.get_candidate_values()) + "\nwith objective values: " + str(
                arc.get_objective_values()) + "\nSatisfying Objective: " + str(
                arc.get_covered_objectives()))
        print("Iteration count: " + str(iteration))
        logger.info("Iteration is : " + str(iteration))
        logger.info("Number of mutations : " + str(MUTATION_NUMBER))

        R_T = []
        
        Q_T = generate_offspring_improved_v2(P_T,model,env,d,objective_uncovered) #generate offsprings using crossover and mutation 

        evaulate_population(func, Q_T, parameters)  # evaluating offspring
        update_archive(Q_T, objective_uncovered, archive, no_of_Objectives, threshold_criteria)  # updating archive
        save_all_data(Q_T,no_of_Objectives,threshold_criteria,second_archive)
        # save generations
        save_all_data2(Q_T,gens)
        R_T = copy.deepcopy(P_T)  # R_T = P_T union Q_T
        R_T.extend(Q_T)

        F = preference_sort(R_T, size, objective_uncovered)  # Preference sorting and getting fronts

        if len(objective_uncovered) == 0:  # checking if all objectives are covered
            print("all_objectives_covered")
            logger.info("***Final-ARCHIVE***")
            print(("***Final-ARCHIVE***"))
            for arc in archive:
                print("\nValues: " + str(
                    arc.get_candidate_values()) + "\nwith objective values: " + str(
                    arc.get_objective_values()) + "\nSatisfying Objective: " + str(
                    arc.get_covered_objectives()))

                logger.info("\nValues: " + str(
                    arc.get_candidate_values()) + "\nwith objective values: " + str(
                    arc.get_objective_values()) + "\nSatisfying Objective: " + str(
                    arc.get_covered_objectives()))
            logger.info("Iteration is : "+str(iteration))
            logger.info("Number of mutations : "+str(MUTATION_NUMBER))
            break

        P_T_1 = []  # creating next generatint PT+1
        index = 0

        while len(P_T_1) <= size:  # if length of current generation is less that size of front at top then add it

            if not isinstance(F[index], Candidate):
                if len(P_T_1) + len(F[index]) > size:
                    break
            else:
                if len(P_T_1) + 1 > size:
                    break

            front = F[index]
            if isinstance(F[index], Candidate):  # if front contains only one item
                P_T_1.append(F[index])
                F.remove(F[index])
            else:
                for ind in range(len(F[index])):  # if front have multiple items
                    val = F[index][ind]
                    P_T_1.append(val)

                F.remove(F[index])
        while (len(P_T_1)) < size:  # crowding distance
            copyFront = copy.deepcopy(F[index])
            sorted_front = sort_worse(copyFront)  # sort before crowding distance

            crowding_distance = get_array_for_crowding_distance(sorted_front)  # coverting to libaray compaitble array
            assign_crowding_distance_to_each_value(sorted_front,
                                                   crowding_distance)  # assinging each solution its crowding distance
            sorted_front.sort(key=sort_based_on_crowding_distance, reverse=True)  # sorting based on crowding distance

            if (len(sorted_front) + len(
                    P_T_1)) > size:  # maintaining length and adding solutions with most crowding distances
                for sorted_front_indx in range(len(sorted_front)):
                    candidate = sorted_front[sorted_front_indx]
                    P_T_1.append(candidate)
                    if len(P_T_1) >= size:
                        break

            index = index + 1

        P_T_1 = P_T_1[0:size]
        P_T = P_T_1  # assigning PT+1 to PT


def minimize(func, population, lb, ub, no_of_Objectives, criteria,time_budget,logger,archive,size,d,env,parameters, second_archive,gens):
    assert hasattr(func, '__call__')

    start = time.time()
    run_search(func, population, no_of_Objectives, criteria,archive,logger,start,time_budget,size,d,env ,parameters, second_archive,gens)

# %%
class CartPole_caseStudy():
    def __init__(self):
        logger = logging.getLogger()

        now = datetime.now()
        log_file = 'output/STARLA' + str(i) + '_V2' + str(now) + '.log'
        logging.basicConfig(filename=log_file,
                            format='%(asctime)s %(message)s')
        self.parameters = [model,d,unique5]
        logger.setLevel(logging.WARNING)
    def _evaluate(self,x):
        fv = x
        model,d,unique5 = self.parameters
        obj1 = fitness_reward(fv)
        obj2 = fitness_confidence(fv,model,'m')
        binary_fv = translator(fv,model,d,unique5)
        obj3 = fitness_functional_probability(RF_FF_1rep,binary_fv)
        obj4 = fitness_functional_probability(RF_RF_1rep,binary_fv)
        to_ret = [obj1,obj2,obj3,obj4]
        logger = logging.getLogger()
        logger.info(str(fv)+","+str(to_ret))
        return to_ret


class MountainCar_caseStudy():
    def __init__(self):
        logger = logging.getLogger()
        now = datetime.now()
        log_file = 'log/STARLA' + str(i) + '_V2' + str(now) + '.log'
        logging.basicConfig(filename=log_file,
                            format='%(asctime)s %(message)s')
        self.parameters = [model,d,unique5]
        logger.setLevel(logging.WARNING)
    def _evaluate(self,x):
        fv = x
        model,d,unique5 = self.parameters
        obj1 = fitness_reward_general(fv)
        if obj1==None:
          debug_data1=[fv,x]
          with open(f'/content/drive/MyDrive/debug/data.pickle', 'wb') as file:
              pickle.dump(debug_data1, file)
          assert False
        obj2 = fitness_confidence_general(fv,model,'m')
        binary_fv = translator(fv,model,d,unique5)
        obj3 = fitness_functional_probability(RF_FF_1rep,binary_fv)
        # obj4 = fitness_functional_probability(RF_RF_1rep,binary_fv)
        to_ret = [obj1,obj2,obj3]
        logger = logging.getLogger()
        logger.info(str(fv)+","+str(to_ret))
        return to_ret


def run(i,population ,archive ,second_archive, gens):
    env=mtc_wrapped
    d=500
    size = len(population)
    lb = [0, 0, 0]
    ub = [100000,1000000,100000]

    parameters = [model,d,unique1]
    threshold_criteria = [-180, 0.04, 0.05]


    no_of_Objectives = 3;

    now = datetime.now()
    global logger
    logger = logging.getLogger()
    log_file = '/content/drive/MyDrive/log/STARLA' + str(i) + '_V2' + str(now) + '.log'
    logging.basicConfig(filename=log_file,
                        format='%(asctime)s %(message)s')

    logger.setLevel(logging.WARNING)

    archive = minimize(MountainCar_caseStudy()._evaluate, population, lb, ub,
                       no_of_Objectives, threshold_criteria, 7200, 
                       logger,archive,size,d,env , parameters, second_archive,gens)
    logger.info("Iteration completed")
    logger.info("mu"+str(MUTATION_NUMBER))

# %% [markdown]
# ###analyzer

# %%
def analyze_result(result):
  '''
  this function is to aggrigate the differences of the results 
  :param `result`: this is the output of the re-execution-improved function
  :return ``:
  '''
  total_dif =0
  # store_diff=[]
  for i in range(len(result)):
    dif = abs(result[i][1][0] - result[i][1][1])
    # store_diff.append([i,dif])
    total_dif += dif
  return total_dif #, store_diff


def get_objective_distribution_and_set_candidate_objectives(population,model,d,
                                                            unique1,RF_FF_1rep,
                                                            RF_RF_1rep):
  fit1_list =[]
  fit2_list =[]
  fit3_list =[]
  fit4_list =[]
  for i in range(len(population)):
    ind_data = population[i].get_candidate_values()
    fit1 = fitness_reward(ind_data)
    fit2 = fitness_confidence(ind_data,model,'m')
    binary_fv = translator(ind_data,model,d,unique1)
    fit3 = fitness_functional_probability(RF_FF_1rep,binary_fv)
    fit4 = fitness_reward_probability(RF_RF_1rep,binary_fv)
    obj = [fit1,fit2,fit3,fit4]
    population[i].set_objective_values(obj)
    fit1_list.append(fit1)
    fit2_list.append(fit2)
    fit3_list.append(fit3)
    fit4_list.append(fit4)
  return   fit1_list, fit2_list, fit3_list, fit4_list 

def get_3objective_distribution_and_set_candidate_objectives(population,model,d,
                                                            unique1,RF_FF_1rep):
  fit1_list =[]
  fit2_list =[]
  fit3_list =[]
  for i in range(len(population)):
    ind_data = population[i].get_candidate_values()
    fit1 = fitness_reward_general(ind_data)
    fit2 = fitness_confidence_general(ind_data,model,'m')
    binary_fv = translator(ind_data,model,d,unique1)
    fit3 = fitness_functional_probability(RF_FF_1rep,binary_fv)
    obj = [fit1,fit2,fit3]
    population[i].set_objective_values(obj)
    fit1_list.append(fit1)
    fit2_list.append(fit2)
    fit3_list.append(fit3)
  return   fit1_list, fit2_list, fit3_list 

def get_objective_distribution(population,model,d,unique1,RF_FF_1rep,RF_RF_1rep):
  fit1_list =[]
  fit2_list =[]
  fit3_list =[]
  fit4_list =[]
  for i in range(len(population)):
    ind_data = population[i].get_candidate_values()
    fit1 = fitness_reward(ind_data)
    fit2 = fitness_confidence(ind_data,model,'m')
    binary_fv = translator(ind_data,model,d,unique1)
    fit3 = fitness_functional_probability(RF_FF_1rep,binary_fv)
    fit4 = fitness_reward_probability(RF_RF_1rep,binary_fv)
    # obj = [fit1,fit2,fit3,fit4]
    # population[i].set_objective_values(obj)
    fit1_list.append(fit1)
    fit2_list.append(fit2)
    fit3_list.append(fit3)
    fit4_list.append(fit4)
  return   fit1_list, fit2_list, fit3_list, fit4_list 


def was_in_initial_population(solution, population,no_of_Objectives):
  flag = False
  for individuals_ in population:
    if individuals_.get_objective_values() == solution.get_objective_values():
      flag = True
  if not flag:
    return solution
  if flag:
    return 0

def analyze_set_differences(differences_set):
  '''
  input is a set of differences 
  '''
  analyzed_results=[]
  for item in differences_set:
    res = [len(item[0]),analyze_result(item[0]), item[1], len(item[0])/item[1]]
    analyzed_results.append(res)
  return analyzed_results

def extract_differences(solution_set):
  '''
  input is a set of solutions like archive or second_archive 
  the output a list ([list of differences as a result of re-execution],reward)
  '''
  differences = []
  for dastan in solution_set:
    reward = dastan.get_objective_values()[0]
    differences.append([re_execution_improved_v2(model,env,dastan),reward])
  return differences
  
def get_results_distribution(results):
  num_of_diff=[]
  diff_confi = []
  diff_ration = []
  for item in results:
    num_of_diff.append(item[0])
    diff_confi.append(item[1])
    diff_ration.append(item[3])
  return num_of_diff, diff_confi, diff_ration

# %%
def random_test_1(model, env, Num):
  obs=env.reset()
  counter = 1
  episode_reward = 0.0
  for i in range(Num):
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, done, info = env.step(action)
    episode_reward += reward
    if done:
      counter += 1
      end = i
      print("Reward:", episode_reward, "final state", info['mem'][-2][0])
      episode_reward = 0.0
      obs = env.reset()
  iter = deepcopy(counter)
  u=1
  while iter>1:
    if info['mem'][-u][0]=='done':
      lastpoint = -u
      iter -= 1
    u+=1
  fin =Num - end
  start = -Num -counter
  randomtest = info['mem'][lastpoint:-fin]
  ran_state = info['state'][(-counter+1):-1]
  return randomtest , ran_state

# %% [markdown]
# ##Model and Data

# %% [markdown]
# ###mountaincar

# %%
def random_test_2(model, env, Num):
  # start= len(info['mem'])
  obs=env.reset()
  counter = 1
  episode_reward = 0.0
  for i in range(Num):
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, done, info = env.step(action)
    episode_reward += reward
    if done:
      counter += 1
      end = i
      episode_reward = 0.0
      obs = env.reset()
  iter = deepcopy(counter)
  u=1
  while iter>1:
    if env.info['mem'][-u][0]=='done':
      lastpoint = -u
      iter -= 1
    u+=1
  fin =Num - end
  start = -Num -counter
  randomtest = env.info['mem'][lastpoint:-fin]
  ran_state = env.info['state'][(-counter+1):-1]
  return randomtest , ran_state

# %%
def is_functional_fault(episode):
  epsilon = 0.1
  env = mtc_wrapped
  reward = episode[-1][1]
  last_state = episode[-2][0][0]
  if last_state<(env.low[0]+epsilon) and reward == -200:
    return True
  else:
    return False


def is_reward_fault(episode):
  RF_threshold = -180
  reward = episode[-1][1]
  # print(len(episode))
  if reward<RF_threshold and len(episode)>200:
    return True
  else:
    return False

def is_functional_fault_last_state(last_step,done_step):
  epsilon = 0.1
  env = mtc_wrapped
  assert done_step[0]=='done', "Wrong input!"
  reward = done_step[1]
  last_state = last_step[0][0]
  if last_state<(env.low[0]+epsilon) and reward == -200:
    return True
  else:
    return False


def is_reward_fault_last_state(last_step,done_step):
  RF_threshold = -180
  assert done_step[0]=='done', "Wrong input!"
  reward = done_step[1]
  last_state = last_step[0][0]
  # print(len(episode))
  if reward<RF_threshold and not is_functional_fault_last_state(last_step,done_step):
    return True
  else:
    return False

# %% [markdown]
# ##wrapper with termination

# %%
class StoreAndTerminateWrapper(gym.Wrapper):
  ''''
  :param env: (gym.Env) Gym environment that will be wrapped
  :param max_steps: (int) Max number of steps per episode
  '''
  def __init__(self, env):
    # Call the parent constructor, so we can access self.env later
    super(StoreAndTerminateWrapper, self).__init__(env)
    self.max_steps = 200
    # Counter of steps per episode
    self.current_step = 0
    self.mem = []
    self.TotalReward = 0.0 
    self.env = env
    self.first_state = 0
    self.first_obs = 0
    self.prev_obs = 0 
    self.states_list = []
    self.info = {}
  
  def reset(self):
    """
    Reset the environment 
    """
    # Reset the counter
    self.current_step = 0
    obs =self.env.reset()
    self.TotalReward = 0.0
    self.first_obs = obs
    return obs

  def step(self, action):
    """
    In this function we store the initial state as well as the memory of the agent
    :param action: ([float] or int) Action taken by the agent
    :return: (np.ndarray, float, bool, dict) observation, reward, is the episode over?, additional informations
    """
    if self.current_step == 0: #store initial state
      self.prev_obs = self.first_obs
      self.first_state = deepcopy(self.env)
      self.states_list.append(self.first_state)
    # print("t",self.env.state[0],"reward",self.TotalReward)
    # if self.env.state[0]==-1.2:
    #   print("-1.2")
    #   obs = self.reset()
    #   reward = -200
    #   done = True
    #   return obs, reward, done, False
    self.current_step += 1
    obs, reward, done, info = self.env.step(action)
    self.TotalReward += reward
    self.mem.append(tuple((self.prev_obs,action)))
    self.prev_obs = obs
    if self.current_step >= self.max_steps:
      done = True
      # Update the info dict to signal that the limit was exceeded
    if obs[0]<=-1.2:
      done = True
      reward = -201 - self.TotalReward
      self.TotalReward =-200
      # print("fff",reward)
    if done:
      self.mem.append(tuple(('done',self.TotalReward)))
    self.info['mem'] = self.mem
    self.info['state'] = self.states_list
    # self.mem.append(tuple(obs,action))
    return obs, reward, done, info

  def set_state(self, state):
    """
    :param state: initial state of the episode
    :return: environment is updated and observations is returned
    """
    self.env = deepcopy(state)
    obs = np.array(list(self.env.unwrapped.state))
    self.current_step = 0
    self.TotalReward = 0.0
    self.first_obs = obs
    return obs

# %% [markdown]
# #Re-execution functions

# %%
# You can skip this part and run Re-execution for extracting similarities
def re_execute_final_ff_v1_woprint_MC(model,env,candidate):
  """This function re-executes the final estimated faults for validation 

  Args:
      model (_type_): Trainned RL model
      env (_type_): Simulation environment
      candidate (_type_): Episode to re-run

  Returns:
      list: contains 3 parameters 
      [(list)states where agent takes another path and is not fixable,
       (list)states where agent takes another action but by adding a slight change to the state we can continue the execution reed section 4.6 in the paper,
       (bool)if functional fault = True]
  """
  differences=[]
  episode_limit = 200 
  env.reset()
  obs =env.set_state(candidate.get_start_state()) 
  episode = candidate.get_candidate_values()
  episode_reward = 0.0
  done =False
  diviate_counter = 0
  divs=[]
  ff=False
  counter = 0 
  for i in range(episode_limit):
    if done:
      done_signal = ('done',episode_reward)
      last_state = (obs,action)
      if is_functional_fault_last_state(last_state,done_signal):
          ff = True
      return differences ,divs, ff
    if i >=(len(episode)-1):
      action, _ = model.predict(obs, deterministic=True)
      obs, reward, done, info = env.step(int(action)) 
      episode_reward += reward
      if done:
        done_signal = ('done',episode_reward)
        last_state = (obs,action)
        if is_functional_fault_last_state(last_state,done_signal):
          ff = True
        return differences ,divs , ff
      continue
    action, _ = model.predict(obs, deterministic=True)
    action1, _ = model.predict(episode[i][0], deterministic=True)
    if action != int(episode[i][1]) and action1 != int(episode[i][1]):
      prob=model.action_probability(episode[i][0])
      differences.append([i , prob])
    if action != int(episode[i][1]):
      diviate_counter+=1
      prob=model.action_probability(episode[i][0])
      divs.append([i , prob])

    obs, reward, done, info = env.step(int(action)) 
    episode_reward += reward
  assert done , "not finished in 200 steps "
  return differences ,divs , ff

# %% [markdown]
# #Run Re-execution

# %%
import os
items = os.listdir('/content/drive/MyDrive/MC/Results/Generations')

Drive_model  ="/content/drive/MyDrive/MTC3/dqn-4-1-6-89946.zip"

mtc = gym.make('MountainCar-v0')
mtc_wrapped = StoreAndTerminateWrapper(mtc)
model = DQN('MlpPolicy',env=mtc_wrapped, verbose=1)
model = model.load(Drive_model)

thresholds = [-180, 0.04, 0.50]
for generations in items[:]:
  if generations=='res' or generations=='.ipynb_checkpoints':
    continue
  arch2=[]
  stat=[]
  ft=[]
  print("\n\n-----------------------------------------------------\n\n")
  print(f'/content/drive/MyDrive/MC/Results/Generations/{generations}')
  with open(f'/content/drive/MyDrive/MC/Results/Generations/{generations}', 'rb') as file2:
      data = pickle.load(file2)
  for i in range(len(data)):
    if i == 0:
      initial_pop = data[i]
      continue
    rewardfault = []
    estimated_functional_faults=[] 
    nonfaulty=[]
    # epsilon = 0.05
    for ind_ in data[i]:
      last_state = ind_.get_candidate_values()[-2]
      value_ = ind_.get_candidate_values()
      objectives_ = ind_.get_objective_values()
      if fitness_reward(value_)<thresholds[0]:
        rewardfault.append(ind_)
      if objectives_[2]<thresholds[2]:
        estimated_functional_faults.append(ind_)
      if fitness_reward(value_)>thresholds[0] and not(is_functional_fault_last_state(last_state,ind_.get_candidate_values()[-1])):
        nonfaulty.append(ind_)
    print("In generation ", i )
    print("Number of estimated functional faults:",len(estimated_functional_faults))
    print("Number of reward faults:",len(rewardfault))
    print("Number of non-faults:",len(nonfaulty))
    print("\n")
    Build_Archive(data[i],3,thresholds,arch2,initial_pop)
  estimated_functional_faults_Archive=[] 
  for epis in arch2:
    objectives_ = epis.get_objective_values()
    if objectives_[2]<thresholds[2]:
      estimated_functional_faults_Archive.append(epis)
  print(f'/content/drive/MyDrive/MC/Results/Generations/{generations}')
  re_exe_results=[]
  for episode in estimated_functional_faults_Archive:
    d1,d2,t = re_execute_final_ff_v1_woprint_MC(model,mtc_wrapped,episode)
    re_exe_results.append([d1,d2,t,episode])
  with open(f'/content/drive/MyDrive/MC/Results/Executions/re_executed{generations}.pickle', 'wb') as file:
    pickle.dump(re_exe_results, file)
# Out:
# Loading a model without an environment, this model cannot be trained until it has a valid environment.
#
#
# -----------------------------------------------------
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run1_7.pickle
# In generation  1
# Number of estimated functional faults: 108
# Number of reward faults: 0
# Number of non-faults: 891
#
#
# In generation  2
# Number of estimated functional faults: 157
# Number of reward faults: 0
# Number of non-faults: 841
#
#
# In generation  3
# Number of estimated functional faults: 165
# Number of reward faults: 0
# Number of non-faults: 833
#
#
# In generation  4
# Number of estimated functional faults: 219
# Number of reward faults: 0
# Number of non-faults: 775
#
#
# In generation  5
# Number of estimated functional faults: 232
# Number of reward faults: 0
# Number of non-faults: 762
#
#
# In generation  6
# Number of estimated functional faults: 263
# Number of reward faults: 0
# Number of non-faults: 728
#
#
# In generation  7
# Number of estimated functional faults: 259
# Number of reward faults: 0
# Number of non-faults: 726
#
#
# In generation  8
# Number of estimated functional faults: 266
# Number of reward faults: 0
# Number of non-faults: 714
#
#
# In generation  9
# Number of estimated functional faults: 306
# Number of reward faults: 0
# Number of non-faults: 686
#
#
# In generation  10
# Number of estimated functional faults: 329
# Number of reward faults: 0
# Number of non-faults: 658
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run1_7.pickle
#
#
# -----------------------------------------------------
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run2_0.pickle
# In generation  1
# Number of estimated functional faults: 93
# Number of reward faults: 0
# Number of non-faults: 906
#
#
# In generation  2
# Number of estimated functional faults: 135
# Number of reward faults: 0
# Number of non-faults: 862
#
#
# In generation  3
# Number of estimated functional faults: 132
# Number of reward faults: 0
# Number of non-faults: 864
#
#
# In generation  4
# Number of estimated functional faults: 147
# Number of reward faults: 0
# Number of non-faults: 845
#
#
# In generation  5
# Number of estimated functional faults: 154
# Number of reward faults: 0
# Number of non-faults: 835
#
#
# In generation  6
# Number of estimated functional faults: 188
# Number of reward faults: 0
# Number of non-faults: 789
#
#
# In generation  7
# Number of estimated functional faults: 202
# Number of reward faults: 0
# Number of non-faults: 766
#
#
# In generation  8
# Number of estimated functional faults: 229
# Number of reward faults: 0
# Number of non-faults: 735
#
#
# In generation  9
# Number of estimated functional faults: 209
# Number of reward faults: 0
# Number of non-faults: 755
#
#
# In generation  10
# Number of estimated functional faults: 255
# Number of reward faults: 0
# Number of non-faults: 699
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run2_0.pickle
#
#
# -----------------------------------------------------
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run2_1.pickle
# In generation  1
# Number of estimated functional faults: 103
# Number of reward faults: 0
# Number of non-faults: 897
#
#
# In generation  2
# Number of estimated functional faults: 156
# Number of reward faults: 0
# Number of non-faults: 844
#
#
# In generation  3
# Number of estimated functional faults: 177
# Number of reward faults: 0
# Number of non-faults: 823
#
#
# In generation  4
# Number of estimated functional faults: 227
# Number of reward faults: 0
# Number of non-faults: 771
#
#
# In generation  5
# Number of estimated functional faults: 218
# Number of reward faults: 0
# Number of non-faults: 778
#
#
# In generation  6
# Number of estimated functional faults: 240
# Number of reward faults: 0
# Number of non-faults: 756
#
#
# In generation  7
# Number of estimated functional faults: 280
# Number of reward faults: 0
# Number of non-faults: 709
#
#
# In generation  8
# Number of estimated functional faults: 276
# Number of reward faults: 0
# Number of non-faults: 709
#
#
# In generation  9
# Number of estimated functional faults: 299
# Number of reward faults: 0
# Number of non-faults: 689
#
#
# In generation  10
# Number of estimated functional faults: 301
# Number of reward faults: 0
# Number of non-faults: 678
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run2_1.pickle
#
#
# -----------------------------------------------------
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run2_2.pickle
# In generation  1
# Number of estimated functional faults: 134
# Number of reward faults: 0
# Number of non-faults: 865
#
#
# In generation  2
# Number of estimated functional faults: 145
# Number of reward faults: 0
# Number of non-faults: 854
#
#
# In generation  3
# Number of estimated functional faults: 209
# Number of reward faults: 0
# Number of non-faults: 786
#
#
# In generation  4
# Number of estimated functional faults: 227
# Number of reward faults: 0
# Number of non-faults: 767
#
#
# In generation  5
# Number of estimated functional faults: 247
# Number of reward faults: 0
# Number of non-faults: 752
#
#
# In generation  6
# Number of estimated functional faults: 262
# Number of reward faults: 0
# Number of non-faults: 724
#
#
# In generation  7
# Number of estimated functional faults: 278
# Number of reward faults: 0
# Number of non-faults: 703
#
#
# In generation  8
# Number of estimated functional faults: 284
# Number of reward faults: 0
# Number of non-faults: 695
#
#
# In generation  9
# Number of estimated functional faults: 304
# Number of reward faults: 0
# Number of non-faults: 684
#
#
# In generation  10
# Number of estimated functional faults: 313
# Number of reward faults: 0
# Number of non-faults: 669
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run2_2.pickle
#
#
# -----------------------------------------------------
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run2_3.pickle
# In generation  1
# Number of estimated functional faults: 86
# Number of reward faults: 0
# Number of non-faults: 914
#
#
# In generation  2
# Number of estimated functional faults: 117
# Number of reward faults: 0
# Number of non-faults: 881
#
#
# In generation  3
# Number of estimated functional faults: 176
# Number of reward faults: 0
# Number of non-faults: 818
#
#
# In generation  4
# Number of estimated functional faults: 206
# Number of reward faults: 0
# Number of non-faults: 779
#
#
# In generation  5
# Number of estimated functional faults: 217
# Number of reward faults: 0
# Number of non-faults: 766
#
#
# In generation  6
# Number of estimated functional faults: 239
# Number of reward faults: 0
# Number of non-faults: 730
#
#
# In generation  7
# Number of estimated functional faults: 263
# Number of reward faults: 0
# Number of non-faults: 708
#
#
# In generation  8
# Number of estimated functional faults: 252
# Number of reward faults: 0
# Number of non-faults: 704
#
#
# In generation  9
# Number of estimated functional faults: 268
# Number of reward faults: 0
# Number of non-faults: 691
#
#
# In generation  10
# Number of estimated functional faults: 286
# Number of reward faults: 0
# Number of non-faults: 675
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run2_3.pickle
#
#
# -----------------------------------------------------
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run2_4.pickle
# In generation  1
# Number of estimated functional faults: 105
# Number of reward faults: 0
# Number of non-faults: 894
#
#
# In generation  2
# Number of estimated functional faults: 153
# Number of reward faults: 0
# Number of non-faults: 847
#
#
# In generation  3
# Number of estimated functional faults: 185
# Number of reward faults: 0
# Number of non-faults: 814
#
#
# In generation  4
# Number of estimated functional faults: 212
# Number of reward faults: 0
# Number of non-faults: 786
#
#
# In generation  5
# Number of estimated functional faults: 223
# Number of reward faults: 0
# Number of non-faults: 775
#
#
# In generation  6
# Number of estimated functional faults: 247
# Number of reward faults: 0
# Number of non-faults: 749
#
#
# In generation  7
# Number of estimated functional faults: 307
# Number of reward faults: 0
# Number of non-faults: 687
#
#
# In generation  8
# Number of estimated functional faults: 297
# Number of reward faults: 0
# Number of non-faults: 695
#
#
# In generation  9
# Number of estimated functional faults: 313
# Number of reward faults: 0
# Number of non-faults: 679
#
#
# In generation  10
# Number of estimated functional faults: 290
# Number of reward faults: 0
# Number of non-faults: 698
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run2_4.pickle
#
#
# -----------------------------------------------------
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run2_5.pickle
# In generation  1
# Number of estimated functional faults: 101
# Number of reward faults: 0
# Number of non-faults: 899
#
#
# In generation  2
# Number of estimated functional faults: 122
# Number of reward faults: 0
# Number of non-faults: 878
#
#
# In generation  3
# Number of estimated functional faults: 160
# Number of reward faults: 0
# Number of non-faults: 841
#
#
# In generation  4
# Number of estimated functional faults: 192
# Number of reward faults: 0
# Number of non-faults: 808
#
#
# In generation  5
# Number of estimated functional faults: 226
# Number of reward faults: 0
# Number of non-faults: 772
#
#
# In generation  6
# Number of estimated functional faults: 199
# Number of reward faults: 0
# Number of non-faults: 800
#
#
# In generation  7
# Number of estimated functional faults: 228
# Number of reward faults: 0
# Number of non-faults: 770
#
#
# In generation  8
# Number of estimated functional faults: 242
# Number of reward faults: 0
# Number of non-faults: 752
#
#
# In generation  9
# Number of estimated functional faults: 211
# Number of reward faults: 0
# Number of non-faults: 779
#
#
# In generation  10
# Number of estimated functional faults: 304
# Number of reward faults: 0
# Number of non-faults: 685
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run2_5.pickle
#
#
# -----------------------------------------------------
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run2_6.pickle
# In generation  1
# Number of estimated functional faults: 97
# Number of reward faults: 0
# Number of non-faults: 902
#
#
# In generation  2
# Number of estimated functional faults: 127
# Number of reward faults: 0
# Number of non-faults: 873
#
#
# In generation  3
# Number of estimated functional faults: 184
# Number of reward faults: 0
# Number of non-faults: 814
#
#
# In generation  4
# Number of estimated functional faults: 201
# Number of reward faults: 0
# Number of non-faults: 796
#
#
# In generation  5
# Number of estimated functional faults: 212
# Number of reward faults: 0
# Number of non-faults: 782
#
#
# In generation  6
# Number of estimated functional faults: 250
# Number of reward faults: 0
# Number of non-faults: 743
#
#
# In generation  7
# Number of estimated functional faults: 280
# Number of reward faults: 0
# Number of non-faults: 701
#
#
# In generation  8
# Number of estimated functional faults: 262
# Number of reward faults: 0
# Number of non-faults: 710
#
#
# In generation  9
# Number of estimated functional faults: 278
# Number of reward faults: 0
# Number of non-faults: 689
#
#
# In generation  10
# Number of estimated functional faults: 282
# Number of reward faults: 0
# Number of non-faults: 667
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run2_6.pickle
#
#
# -----------------------------------------------------
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run2_7.pickle
# In generation  1
# Number of estimated functional faults: 123
# Number of reward faults: 0
# Number of non-faults: 877
#
#
# In generation  2
# Number of estimated functional faults: 122
# Number of reward faults: 0
# Number of non-faults: 878
#
#
# In generation  3
# Number of estimated functional faults: 170
# Number of reward faults: 0
# Number of non-faults: 829
#
#
# In generation  4
# Number of estimated functional faults: 181
# Number of reward faults: 0
# Number of non-faults: 817
#
#
# In generation  5
# Number of estimated functional faults: 203
# Number of reward faults: 0
# Number of non-faults: 791
#
#
# In generation  6
# Number of estimated functional faults: 191
# Number of reward faults: 0
# Number of non-faults: 801
#
#
# In generation  7
# Number of estimated functional faults: 242
# Number of reward faults: 0
# Number of non-faults: 753
#
#
# In generation  8
# Number of estimated functional faults: 277
# Number of reward faults: 0
# Number of non-faults: 714
#
#
# In generation  9
# Number of estimated functional faults: 269
# Number of reward faults: 0
# Number of non-faults: 718
#
#
# In generation  10
# Number of estimated functional faults: 251
# Number of reward faults: 0
# Number of non-faults: 736
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run2_7.pickle
#
#
# -----------------------------------------------------
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run2_8.pickle
# In generation  1
# Number of estimated functional faults: 99
# Number of reward faults: 0
# Number of non-faults: 900
#
#
# In generation  2
# Number of estimated functional faults: 136
# Number of reward faults: 0
# Number of non-faults: 863
#
#
# In generation  3
# Number of estimated functional faults: 128
# Number of reward faults: 0
# Number of non-faults: 872
#
#
# In generation  4
# Number of estimated functional faults: 179
# Number of reward faults: 0
# Number of non-faults: 817
#
#
# In generation  5
# Number of estimated functional faults: 208
# Number of reward faults: 0
# Number of non-faults: 788
#
#
# In generation  6
# Number of estimated functional faults: 219
# Number of reward faults: 0
# Number of non-faults: 775
#
#
# In generation  7
# Number of estimated functional faults: 254
# Number of reward faults: 0
# Number of non-faults: 739
#
#
# In generation  8
# Number of estimated functional faults: 254
# Number of reward faults: 0
# Number of non-faults: 731
#
#
# In generation  9
# Number of estimated functional faults: 250
# Number of reward faults: 0
# Number of non-faults: 748
#
#
# In generation  10
# Number of estimated functional faults: 273
# Number of reward faults: 0
# Number of non-faults: 724
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run2_8.pickle
#
#
# -----------------------------------------------------
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run0_0.pickle
# In generation  1
# Number of estimated functional faults: 107
# Number of reward faults: 0
# Number of non-faults: 892
#
#
# In generation  2
# Number of estimated functional faults: 128
# Number of reward faults: 0
# Number of non-faults: 873
#
#
# In generation  3
# Number of estimated functional faults: 165
# Number of reward faults: 0
# Number of non-faults: 830
#
#
# In generation  4
# Number of estimated functional faults: 193
# Number of reward faults: 0
# Number of non-faults: 801
#
#
# In generation  5
# Number of estimated functional faults: 231
# Number of reward faults: 0
# Number of non-faults: 757
#
#
# In generation  6
# Number of estimated functional faults: 248
# Number of reward faults: 0
# Number of non-faults: 743
#
#
# In generation  7
# Number of estimated functional faults: 257
# Number of reward faults: 0
# Number of non-faults: 723
#
#
# In generation  8
# Number of estimated functional faults: 288
# Number of reward faults: 0
# Number of non-faults: 686
#
#
# In generation  9
# Number of estimated functional faults: 304
# Number of reward faults: 0
# Number of non-faults: 665
#
#
# In generation  10
# Number of estimated functional faults: 306
# Number of reward faults: 0
# Number of non-faults: 667
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run0_0.pickle
#
#
# -----------------------------------------------------
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run0_1.pickle
# In generation  1
# Number of estimated functional faults: 65
# Number of reward faults: 0
# Number of non-faults: 935
#
#
# In generation  2
# Number of estimated functional faults: 112
# Number of reward faults: 0
# Number of non-faults: 887
#
#
# In generation  3
# Number of estimated functional faults: 132
# Number of reward faults: 0
# Number of non-faults: 865
#
#
# In generation  4
# Number of estimated functional faults: 121
# Number of reward faults: 0
# Number of non-faults: 873
#
#
# In generation  5
# Number of estimated functional faults: 165
# Number of reward faults: 0
# Number of non-faults: 832
#
#
# In generation  6
# Number of estimated functional faults: 179
# Number of reward faults: 0
# Number of non-faults: 819
#
#
# In generation  7
# Number of estimated functional faults: 197
# Number of reward faults: 0
# Number of non-faults: 800
#
#
# In generation  8
# Number of estimated functional faults: 236
# Number of reward faults: 0
# Number of non-faults: 762
#
#
# In generation  9
# Number of estimated functional faults: 271
# Number of reward faults: 0
# Number of non-faults: 715
#
#
# In generation  10
# Number of estimated functional faults: 276
# Number of reward faults: 0
# Number of non-faults: 716
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run0_1.pickle
#
#
# -----------------------------------------------------
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run0_2.pickle
# In generation  1
# Number of estimated functional faults: 80
# Number of reward faults: 0
# Number of non-faults: 921
#
#
# In generation  2
# Number of estimated functional faults: 114
# Number of reward faults: 0
# Number of non-faults: 886
#
#
# In generation  3
# Number of estimated functional faults: 152
# Number of reward faults: 0
# Number of non-faults: 848
#
#
# In generation  4
# Number of estimated functional faults: 165
# Number of reward faults: 0
# Number of non-faults: 832
#
#
# In generation  5
# Number of estimated functional faults: 195
# Number of reward faults: 0
# Number of non-faults: 802
#
#
# In generation  6
# Number of estimated functional faults: 218
# Number of reward faults: 0
# Number of non-faults: 775
#
#
# In generation  7
# Number of estimated functional faults: 239
# Number of reward faults: 0
# Number of non-faults: 753
#
#
# In generation  8
# Number of estimated functional faults: 257
# Number of reward faults: 0
# Number of non-faults: 736
#
#
# In generation  9
# Number of estimated functional faults: 274
# Number of reward faults: 0
# Number of non-faults: 721
#
#
# In generation  10
# Number of estimated functional faults: 267
# Number of reward faults: 0
# Number of non-faults: 725
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run0_2.pickle
#
#
# -----------------------------------------------------
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run0_3.pickle
# In generation  1
# Number of estimated functional faults: 99
# Number of reward faults: 0
# Number of non-faults: 901
#
#
# In generation  2
# Number of estimated functional faults: 138
# Number of reward faults: 0
# Number of non-faults: 859
#
#
# In generation  3
# Number of estimated functional faults: 174
# Number of reward faults: 0
# Number of non-faults: 825
#
#
# In generation  4
# Number of estimated functional faults: 200
# Number of reward faults: 0
# Number of non-faults: 796
#
#
# In generation  5
# Number of estimated functional faults: 226
# Number of reward faults: 0
# Number of non-faults: 768
#
#
# In generation  6
# Number of estimated functional faults: 297
# Number of reward faults: 0
# Number of non-faults: 696
#
#
# In generation  7
# Number of estimated functional faults: 269
# Number of reward faults: 0
# Number of non-faults: 723
#
#
# In generation  8
# Number of estimated functional faults: 315
# Number of reward faults: 0
# Number of non-faults: 675
#
#
# In generation  9
# Number of estimated functional faults: 347
# Number of reward faults: 0
# Number of non-faults: 634
#
#
# In generation  10
# Number of estimated functional faults: 316
# Number of reward faults: 0
# Number of non-faults: 667
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run0_3.pickle
#
#
# -----------------------------------------------------
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run0_4.pickle
# In generation  1
# Number of estimated functional faults: 92
# Number of reward faults: 0
# Number of non-faults: 908
#
#
# In generation  2
# Number of estimated functional faults: 121
# Number of reward faults: 0
# Number of non-faults: 879
#
#
# In generation  3
# Number of estimated functional faults: 169
# Number of reward faults: 0
# Number of non-faults: 830
#
#
# In generation  4
# Number of estimated functional faults: 186
# Number of reward faults: 0
# Number of non-faults: 813
#
#
# In generation  5
# Number of estimated functional faults: 217
# Number of reward faults: 0
# Number of non-faults: 782
#
#
# In generation  6
# Number of estimated functional faults: 217
# Number of reward faults: 0
# Number of non-faults: 780
#
#
# In generation  7
# Number of estimated functional faults: 247
# Number of reward faults: 0
# Number of non-faults: 751
#
#
# In generation  8
# Number of estimated functional faults: 257
# Number of reward faults: 0
# Number of non-faults: 740
#
#
# In generation  9
# Number of estimated functional faults: 265
# Number of reward faults: 0
# Number of non-faults: 733
#
#
# In generation  10
# Number of estimated functional faults: 255
# Number of reward faults: 0
# Number of non-faults: 741
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run0_4.pickle
#
#
# -----------------------------------------------------
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run0_5.pickle
# In generation  1
# Number of estimated functional faults: 94
# Number of reward faults: 0
# Number of non-faults: 906
#
#
# In generation  2
# Number of estimated functional faults: 120
# Number of reward faults: 0
# Number of non-faults: 881
#
#
# In generation  3
# Number of estimated functional faults: 163
# Number of reward faults: 0
# Number of non-faults: 837
#
#
# In generation  4
# Number of estimated functional faults: 156
# Number of reward faults: 0
# Number of non-faults: 844
#
#
# In generation  5
# Number of estimated functional faults: 188
# Number of reward faults: 0
# Number of non-faults: 810
#
#
# In generation  6
# Number of estimated functional faults: 198
# Number of reward faults: 0
# Number of non-faults: 800
#
#
# In generation  7
# Number of estimated functional faults: 211
# Number of reward faults: 0
# Number of non-faults: 786
#
#
# In generation  8
# Number of estimated functional faults: 218
# Number of reward faults: 0
# Number of non-faults: 778
#
#
# In generation  9
# Number of estimated functional faults: 221
# Number of reward faults: 0
# Number of non-faults: 772
#
#
# In generation  10
# Number of estimated functional faults: 233
# Number of reward faults: 0
# Number of non-faults: 755
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run0_5.pickle
#
#
# -----------------------------------------------------
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run0_6.pickle
# In generation  1
# Number of estimated functional faults: 88
# Number of reward faults: 0
# Number of non-faults: 912
#
#
# In generation  2
# Number of estimated functional faults: 152
# Number of reward faults: 0
# Number of non-faults: 847
#
#
# In generation  3
# Number of estimated functional faults: 162
# Number of reward faults: 0
# Number of non-faults: 837
#
#
# In generation  4
# Number of estimated functional faults: 194
# Number of reward faults: 0
# Number of non-faults: 806
#
#
# In generation  5
# Number of estimated functional faults: 215
# Number of reward faults: 0
# Number of non-faults: 784
#
#
# In generation  6
# Number of estimated functional faults: 232
# Number of reward faults: 0
# Number of non-faults: 767
#
#
# In generation  7
# Number of estimated functional faults: 265
# Number of reward faults: 0
# Number of non-faults: 728
#
#
# In generation  8
# Number of estimated functional faults: 258
# Number of reward faults: 0
# Number of non-faults: 736
#
#
# In generation  9
# Number of estimated functional faults: 284
# Number of reward faults: 0
# Number of non-faults: 710
#
#
# In generation  10
# Number of estimated functional faults: 269
# Number of reward faults: 0
# Number of non-faults: 722
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run0_6.pickle
#
#
# -----------------------------------------------------
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run0_7.pickle
# In generation  1
# Number of estimated functional faults: 87
# Number of reward faults: 0
# Number of non-faults: 914
#
#
# In generation  2
# Number of estimated functional faults: 125
# Number of reward faults: 0
# Number of non-faults: 875
#
#
# In generation  3
# Number of estimated functional faults: 150
# Number of reward faults: 0
# Number of non-faults: 850
#
#
# In generation  4
# Number of estimated functional faults: 183
# Number of reward faults: 0
# Number of non-faults: 816
#
#
# In generation  5
# Number of estimated functional faults: 225
# Number of reward faults: 0
# Number of non-faults: 772
#
#
# In generation  6
# Number of estimated functional faults: 237
# Number of reward faults: 0
# Number of non-faults: 759
#
#
# In generation  7
# Number of estimated functional faults: 255
# Number of reward faults: 0
# Number of non-faults: 742
#
#
# In generation  8
# Number of estimated functional faults: 278
# Number of reward faults: 0
# Number of non-faults: 717
#
#
# In generation  9
# Number of estimated functional faults: 254
# Number of reward faults: 0
# Number of non-faults: 738
#
#
# In generation  10
# Number of estimated functional faults: 260
# Number of reward faults: 0
# Number of non-faults: 733
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run0_7.pickle
#
#
# -----------------------------------------------------
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run1_0.pickle
# In generation  1
# Number of estimated functional faults: 100
# Number of reward faults: 0
# Number of non-faults: 901
#
#
# In generation  2
# Number of estimated functional faults: 130
# Number of reward faults: 0
# Number of non-faults: 869
#
#
# In generation  3
# Number of estimated functional faults: 174
# Number of reward faults: 0
# Number of non-faults: 826
#
#
# In generation  4
# Number of estimated functional faults: 170
# Number of reward faults: 0
# Number of non-faults: 829
#
#
# In generation  5
# Number of estimated functional faults: 232
# Number of reward faults: 0
# Number of non-faults: 767
#
#
# In generation  6
# Number of estimated functional faults: 260
# Number of reward faults: 0
# Number of non-faults: 737
#
#
# In generation  7
# Number of estimated functional faults: 267
# Number of reward faults: 0
# Number of non-faults: 725
#
#
# In generation  8
# Number of estimated functional faults: 281
# Number of reward faults: 0
# Number of non-faults: 710
#
#
# In generation  9
# Number of estimated functional faults: 292
# Number of reward faults: 0
# Number of non-faults: 691
#
#
# In generation  10
# Number of estimated functional faults: 306
# Number of reward faults: 0
# Number of non-faults: 684
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run1_0.pickle
#
#
# -----------------------------------------------------
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run1_1.pickle
# In generation  1
# Number of estimated functional faults: 87
# Number of reward faults: 0
# Number of non-faults: 913
#
#
# In generation  2
# Number of estimated functional faults: 108
# Number of reward faults: 0
# Number of non-faults: 892
#
#
# In generation  3
# Number of estimated functional faults: 126
# Number of reward faults: 0
# Number of non-faults: 873
#
#
# In generation  4
# Number of estimated functional faults: 123
# Number of reward faults: 0
# Number of non-faults: 871
#
#
# In generation  5
# Number of estimated functional faults: 158
# Number of reward faults: 0
# Number of non-faults: 835
#
#
# In generation  6
# Number of estimated functional faults: 218
# Number of reward faults: 0
# Number of non-faults: 775
#
#
# In generation  7
# Number of estimated functional faults: 195
# Number of reward faults: 0
# Number of non-faults: 803
#
#
# In generation  8
# Number of estimated functional faults: 233
# Number of reward faults: 0
# Number of non-faults: 759
#
#
# In generation  9
# Number of estimated functional faults: 275
# Number of reward faults: 0
# Number of non-faults: 720
#
#
# In generation  10
# Number of estimated functional faults: 309
# Number of reward faults: 0
# Number of non-faults: 667
#
#
# /content/drive/MyDrive/MC/Results/Generations/Copy of Oct30_generations_population1000lastfull_run1_1.pickle
# time: 1h 44min 10s (started: 2022-11-06 19:13:51 +00:00)

# %% [markdown]
# #Re-execution for extracting similarities between states

# %%
def re_execute_final_ff_similarity_woprint_MC(model,env,candidate):
  """Re-execution function returning real states  from simulator. This will then be used to extract the cosine distances.

  Args:
      model (_type_): Trainned RL model
      env (_type_): Simulation environment
      candidate (_type_): Episode to re-run

  Returns:
      list: contains 4 parameters 
      [(list)states where agent takes another path and is not fixable,
       (list)states where agent takes another action (diviation) but by adding a slight change to the state we can continue the execution reed section 4.6 in the paper,
       (bool)if functional fault = True,
       (list)list of pairs of states where diviations occured]
  """
  differences=[]
  episode_limit = 200 
  env.reset()
  obs =env.set_state(candidate.get_start_state()) 
  episode = candidate.get_candidate_values()
  episode_reward = 0.0
  done =False
  diviate_counter = 0
  divs=[]
  States=[]
  ff=False
  counter = 0 
  for i in range(episode_limit):
    if done:
      done_signal = ('done',episode_reward)
      last_state = (obs,action)
      if is_functional_fault_last_state(last_state,done_signal):
          ff = True
      return differences ,divs, ff, States
    if i >=(len(episode)-1):
      action, _ = model.predict(obs, deterministic=True)
      obs, reward, done, info = env.step(int(action)) 
      episode_reward += reward
      if done:
        done_signal = ('done',episode_reward)
        last_state = (obs,action)
        if is_functional_fault_last_state(last_state,done_signal):
          ff = True
        return differences ,divs , ff, States
      continue
    action, _ = model.predict(obs, deterministic=True)
    action1, _ = model.predict(episode[i][0], deterministic=True)
    if action != int(episode[i][1]) and action1 != int(episode[i][1]):
      prob=model.action_probability(episode[i][0])
      differences.append([i , prob])
    if action != int(episode[i][1]):
      diviate_counter+=1
      prob=model.action_probability(episode[i][0])
      divs.append([i , prob])
      States.append([obs,episode[i][0]])

    obs, reward, done, info = env.step(int(action)) 
    episode_reward += reward
  assert done , "not finished in 200 steps "
  return differences ,divs , ff, States

# %%
import os
items = os.listdir('c:/Users/Student/Desktop/Data/NewResults1207/Generation/')

Drive_model  ="c:/Users/Student/Desktop/Data/dqn-4-1-6-89946.zip"

mtc = gym.make('MountainCar-v0')
mtc_wrapped = StoreAndTerminateWrapper(mtc)
model = DQN('MlpPolicy',env=mtc_wrapped, verbose=1)
model = model.load(Drive_model)

thresholds = [-180, 0.04, 0.50]
for generations in items:
  if generations=='res' or generations=='.ipynb_checkpoints' or generations=='Extra':
    continue
  arch2=[]
  stat=[]
  ft=[]
  print("\n\n-----------------------------------------------------\n\n")
  print(f'c:/Users/Student/Desktop/Data/NewResults1207/Generation/{generations}')
  with open(f'c:/Users/Student/Desktop/Data/NewResults1207/Generation/{generations}', 'rb') as file2:
      data = pickle.load(file2)
  for i in range(len(data)):
    if i == 0:
      initial_pop = data[i]
      continue
    rewardfault = []
    estimated_functional_faults=[] 
    nonfaulty=[]
    # epsilon = 0.05
    for ind_ in data[i]:
      last_state = ind_.get_candidate_values()[-2]
      value_ = ind_.get_candidate_values()
      objectives_ = ind_.get_objective_values()
      if fitness_reward(value_)<thresholds[0]:
        rewardfault.append(ind_)
      if objectives_[2]<thresholds[2]:
        estimated_functional_faults.append(ind_)
      if fitness_reward(value_)>thresholds[0] and not(is_functional_fault_last_state(last_state,ind_.get_candidate_values()[-1])):
        nonfaulty.append(ind_)
    print("In generation ", i )
    print("Number of estimated functional faults:",len(estimated_functional_faults))
    print("Number of reward faults:",len(rewardfault))
    print("Number of non-faults:",len(nonfaulty))
    print("\n")
    Build_Archive(data[i],3,thresholds,arch2,initial_pop)
  estimated_functional_faults_Archive=[] 
  for epis in arch2:
    objectives_ = epis.get_objective_values()
    if objectives_[2]<thresholds[2]:
      estimated_functional_faults_Archive.append(epis)
  print(f'c:/Users/Student/Desktop/Data/NewResults1207/Generation/{generations}')
  re_exe_results=[]
  for episode in estimated_functional_faults_Archive:
    d1,d2,t,states = re_execute_final_ff_similarity_woprint_MC(model,mtc_wrapped,episode)
    
    re_exe_results.append([d1,d2,t,states,episode])
  with open(f'c:/Users/Student/Desktop/Data/NewResults1207/Exe_Sim/re_executed{generations}.pickle', 'wb') as file:
    pickle.dump(re_exe_results, file)
# Out:
# WARNING:tensorflow:From c:\Users\Student\Desktop\vs_git\.virtualenvs\venv\lib\site-packages\stable_baselines\common\tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From c:\Users\Student\Desktop\vs_git\.virtualenvs\venv\lib\site-packages\stable_baselines\common\tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From c:\Users\Student\Desktop\vs_git\.virtualenvs\venv\lib\site-packages\stable_baselines\deepq\dqn.py:129: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From c:\Users\Student\Desktop\vs_git\.virtualenvs\venv\lib\site-packages\stable_baselines\deepq\build_graph.py:358: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From c:\Users\Student\Desktop\vs_git\.virtualenvs\venv\lib\site-packages\stable_baselines\deepq\build_graph.py:359: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From c:\Users\Student\Desktop\vs_git\.virtualenvs\venv\lib\site-packages\stable_baselines\deepq\build_graph.py:139: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From c:\Users\Student\Desktop\vs_git\.virtualenvs\venv\lib\site-packages\stable_baselines\deepq\policies.py:109: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From c:\Users\Student\Desktop\vs_git\.virtualenvs\venv\lib\site-packages\tensorflow_core\python\layers\core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From c:\Users\Student\Desktop\vs_git\.virtualenvs\venv\lib\site-packages\stable_baselines\deepq\build_graph.py:147: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From c:\Users\Student\Desktop\vs_git\.virtualenvs\venv\lib\site-packages\stable_baselines\deepq\build_graph.py:149: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From c:\Users\Student\Desktop\vs_git\.virtualenvs\venv\lib\site-packages\stable_baselines\deepq\build_graph.py:372: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From c:\Users\Student\Desktop\vs_git\.virtualenvs\venv\lib\site-packages\stable_baselines\deepq\build_graph.py:372: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From c:\Users\Student\Desktop\vs_git\.virtualenvs\venv\lib\site-packages\stable_baselines\deepq\build_graph.py:372: The name tf.get_variable_scope is deprecated. Please use tf.compat.v1.get_variable_scope instead.
#
# WARNING:tensorflow:From c:\Users\Student\Desktop\vs_git\.virtualenvs\venv\lib\site-packages\stable_baselines\deepq\build_graph.py:415: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From c:\Users\Student\Desktop\vs_git\.virtualenvs\venv\lib\site-packages\stable_baselines\deepq\build_graph.py:449: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From c:\Users\Student\Desktop\vs_git\.virtualenvs\venv\lib\site-packages\stable_baselines\common\tf_util.py:241: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From c:\Users\Student\Desktop\vs_git\.virtualenvs\venv\lib\site-packages\stable_baselines\common\tf_util.py:242: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# Loading a model without an environment, this model cannot be trained until it has a valid environment.
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run0_0.pickle
# In generation  1
# Number of estimated functional faults: 149
# Number of reward faults: 0
# Number of non-faults: 1350
#
#
# In generation  2
# Number of estimated functional faults: 194
# Number of reward faults: 0
# Number of non-faults: 1307
#
#
# In generation  3
# Number of estimated functional faults: 226
# Number of reward faults: 0
# Number of non-faults: 1274
#
#
# In generation  4
# Number of estimated functional faults: 259
# Number of reward faults: 0
# Number of non-faults: 1239
#
#
# In generation  5
# Number of estimated functional faults: 309
# Number of reward faults: 0
# Number of non-faults: 1187
#
#
# In generation  6
# Number of estimated functional faults: 337
# Number of reward faults: 0
# Number of non-faults: 1157
#
#
# In generation  7
# Number of estimated functional faults: 334
# Number of reward faults: 0
# Number of non-faults: 1155
#
#
# In generation  8
# Number of estimated functional faults: 408
# Number of reward faults: 0
# Number of non-faults: 1076
#
#
# In generation  9
# Number of estimated functional faults: 433
# Number of reward faults: 0
# Number of non-faults: 1058
#
#
# In generation  10
# Number of estimated functional faults: 429
# Number of reward faults: 0
# Number of non-faults: 1053
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run0_0.pickle
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run0_1.pickle
# In generation  1
# Number of estimated functional faults: 143
# Number of reward faults: 0
# Number of non-faults: 1358
#
#
# In generation  2
# Number of estimated functional faults: 187
# Number of reward faults: 0
# Number of non-faults: 1314
#
#
# In generation  3
# Number of estimated functional faults: 267
# Number of reward faults: 0
# Number of non-faults: 1232
#
#
# In generation  4
# Number of estimated functional faults: 293
# Number of reward faults: 0
# Number of non-faults: 1208
#
#
# In generation  5
# Number of estimated functional faults: 370
# Number of reward faults: 0
# Number of non-faults: 1130
#
#
# In generation  6
# Number of estimated functional faults: 416
# Number of reward faults: 0
# Number of non-faults: 1080
#
#
# In generation  7
# Number of estimated functional faults: 448
# Number of reward faults: 0
# Number of non-faults: 1045
#
#
# In generation  8
# Number of estimated functional faults: 516
# Number of reward faults: 0
# Number of non-faults: 975
#
#
# In generation  9
# Number of estimated functional faults: 525
# Number of reward faults: 0
# Number of non-faults: 965
#
#
# In generation  10
# Number of estimated functional faults: 567
# Number of reward faults: 0
# Number of non-faults: 920
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run0_1.pickle
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run0_2.pickle
# In generation  1
# Number of estimated functional faults: 140
# Number of reward faults: 0
# Number of non-faults: 1357
#
#
# In generation  2
# Number of estimated functional faults: 171
# Number of reward faults: 0
# Number of non-faults: 1327
#
#
# In generation  3
# Number of estimated functional faults: 215
# Number of reward faults: 0
# Number of non-faults: 1280
#
#
# In generation  4
# Number of estimated functional faults: 244
# Number of reward faults: 0
# Number of non-faults: 1244
#
#
# In generation  5
# Number of estimated functional faults: 324
# Number of reward faults: 0
# Number of non-faults: 1166
#
#
# In generation  6
# Number of estimated functional faults: 348
# Number of reward faults: 0
# Number of non-faults: 1133
#
#
# In generation  7
# Number of estimated functional faults: 378
# Number of reward faults: 0
# Number of non-faults: 1112
#
#
# In generation  8
# Number of estimated functional faults: 401
# Number of reward faults: 0
# Number of non-faults: 1085
#
#
# In generation  9
# Number of estimated functional faults: 453
# Number of reward faults: 0
# Number of non-faults: 1032
#
#
# In generation  10
# Number of estimated functional faults: 515
# Number of reward faults: 0
# Number of non-faults: 967
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run0_2.pickle
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run0_3.pickle
# In generation  1
# Number of estimated functional faults: 159
# Number of reward faults: 0
# Number of non-faults: 1339
#
#
# In generation  2
# Number of estimated functional faults: 204
# Number of reward faults: 0
# Number of non-faults: 1293
#
#
# In generation  3
# Number of estimated functional faults: 270
# Number of reward faults: 0
# Number of non-faults: 1225
#
#
# In generation  4
# Number of estimated functional faults: 319
# Number of reward faults: 0
# Number of non-faults: 1169
#
#
# In generation  5
# Number of estimated functional faults: 331
# Number of reward faults: 0
# Number of non-faults: 1141
#
#
# In generation  6
# Number of estimated functional faults: 376
# Number of reward faults: 0
# Number of non-faults: 1090
#
#
# In generation  7
# Number of estimated functional faults: 431
# Number of reward faults: 0
# Number of non-faults: 1033
#
#
# In generation  8
# Number of estimated functional faults: 435
# Number of reward faults: 0
# Number of non-faults: 1018
#
#
# In generation  9
# Number of estimated functional faults: 508
# Number of reward faults: 0
# Number of non-faults: 955
#
#
# In generation  10
# Number of estimated functional faults: 533
# Number of reward faults: 0
# Number of non-faults: 929
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run0_3.pickle
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run0_4.pickle
# In generation  1
# Number of estimated functional faults: 151
# Number of reward faults: 0
# Number of non-faults: 1348
#
#
# In generation  2
# Number of estimated functional faults: 178
# Number of reward faults: 0
# Number of non-faults: 1323
#
#
# In generation  3
# Number of estimated functional faults: 241
# Number of reward faults: 0
# Number of non-faults: 1260
#
#
# In generation  4
# Number of estimated functional faults: 286
# Number of reward faults: 0
# Number of non-faults: 1215
#
#
# In generation  5
# Number of estimated functional faults: 311
# Number of reward faults: 0
# Number of non-faults: 1188
#
#
# In generation  6
# Number of estimated functional faults: 341
# Number of reward faults: 0
# Number of non-faults: 1155
#
#
# In generation  7
# Number of estimated functional faults: 395
# Number of reward faults: 0
# Number of non-faults: 1094
#
#
# In generation  8
# Number of estimated functional faults: 401
# Number of reward faults: 0
# Number of non-faults: 1078
#
#
# In generation  9
# Number of estimated functional faults: 463
# Number of reward faults: 0
# Number of non-faults: 1013
#
#
# In generation  10
# Number of estimated functional faults: 508
# Number of reward faults: 0
# Number of non-faults: 963
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run0_4.pickle
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run0_5.pickle
# In generation  1
# Number of estimated functional faults: 137
# Number of reward faults: 0
# Number of non-faults: 1363
#
#
# In generation  2
# Number of estimated functional faults: 174
# Number of reward faults: 0
# Number of non-faults: 1327
#
#
# In generation  3
# Number of estimated functional faults: 222
# Number of reward faults: 0
# Number of non-faults: 1275
#
#
# In generation  4
# Number of estimated functional faults: 270
# Number of reward faults: 0
# Number of non-faults: 1229
#
#
# In generation  5
# Number of estimated functional faults: 287
# Number of reward faults: 0
# Number of non-faults: 1208
#
#
# In generation  6
# Number of estimated functional faults: 351
# Number of reward faults: 0
# Number of non-faults: 1142
#
#
# In generation  7
# Number of estimated functional faults: 395
# Number of reward faults: 0
# Number of non-faults: 1096
#
#
# In generation  8
# Number of estimated functional faults: 416
# Number of reward faults: 0
# Number of non-faults: 1069
#
#
# In generation  9
# Number of estimated functional faults: 506
# Number of reward faults: 0
# Number of non-faults: 981
#
#
# In generation  10
# Number of estimated functional faults: 524
# Number of reward faults: 0
# Number of non-faults: 952
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run0_5.pickle
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run0_6.pickle
# In generation  1
# Number of estimated functional faults: 120
# Number of reward faults: 0
# Number of non-faults: 1378
#
#
# In generation  2
# Number of estimated functional faults: 184
# Number of reward faults: 0
# Number of non-faults: 1313
#
#
# In generation  3
# Number of estimated functional faults: 227
# Number of reward faults: 0
# Number of non-faults: 1266
#
#
# In generation  4
# Number of estimated functional faults: 232
# Number of reward faults: 0
# Number of non-faults: 1249
#
#
# In generation  5
# Number of estimated functional faults: 295
# Number of reward faults: 0
# Number of non-faults: 1189
#
#
# In generation  6
# Number of estimated functional faults: 323
# Number of reward faults: 0
# Number of non-faults: 1148
#
#
# In generation  7
# Number of estimated functional faults: 383
# Number of reward faults: 0
# Number of non-faults: 1074
#
#
# In generation  8
# Number of estimated functional faults: 348
# Number of reward faults: 0
# Number of non-faults: 1114
#
#
# In generation  9
# Number of estimated functional faults: 415
# Number of reward faults: 0
# Number of non-faults: 1046
#
#
# In generation  10
# Number of estimated functional faults: 477
# Number of reward faults: 0
# Number of non-faults: 960
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run0_6.pickle
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run0_7.pickle
# In generation  1
# Number of estimated functional faults: 150
# Number of reward faults: 0
# Number of non-faults: 1350
#
#
# In generation  2
# Number of estimated functional faults: 180
# Number of reward faults: 0
# Number of non-faults: 1317
#
#
# In generation  3
# Number of estimated functional faults: 236
# Number of reward faults: 0
# Number of non-faults: 1258
#
#
# In generation  4
# Number of estimated functional faults: 290
# Number of reward faults: 0
# Number of non-faults: 1204
#
#
# In generation  5
# Number of estimated functional faults: 295
# Number of reward faults: 0
# Number of non-faults: 1200
#
#
# In generation  6
# Number of estimated functional faults: 355
# Number of reward faults: 0
# Number of non-faults: 1131
#
#
# In generation  7
# Number of estimated functional faults: 396
# Number of reward faults: 0
# Number of non-faults: 1094
#
#
# In generation  8
# Number of estimated functional faults: 398
# Number of reward faults: 0
# Number of non-faults: 1090
#
#
# In generation  9
# Number of estimated functional faults: 468
# Number of reward faults: 0
# Number of non-faults: 1007
#
#
# In generation  10
# Number of estimated functional faults: 489
# Number of reward faults: 0
# Number of non-faults: 987
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run0_7.pickle
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run0_8.pickle
# In generation  1
# Number of estimated functional faults: 165
# Number of reward faults: 0
# Number of non-faults: 1333
#
#
# In generation  2
# Number of estimated functional faults: 229
# Number of reward faults: 0
# Number of non-faults: 1267
#
#
# In generation  3
# Number of estimated functional faults: 247
# Number of reward faults: 0
# Number of non-faults: 1249
#
#
# In generation  4
# Number of estimated functional faults: 318
# Number of reward faults: 0
# Number of non-faults: 1170
#
#
# In generation  5
# Number of estimated functional faults: 368
# Number of reward faults: 0
# Number of non-faults: 1106
#
#
# In generation  6
# Number of estimated functional faults: 448
# Number of reward faults: 0
# Number of non-faults: 1029
#
#
# In generation  7
# Number of estimated functional faults: 445
# Number of reward faults: 0
# Number of non-faults: 1028
#
#
# In generation  8
# Number of estimated functional faults: 489
# Number of reward faults: 0
# Number of non-faults: 1000
#
#
# In generation  9
# Number of estimated functional faults: 512
# Number of reward faults: 0
# Number of non-faults: 965
#
#
# In generation  10
# Number of estimated functional faults: 504
# Number of reward faults: 0
# Number of non-faults: 962
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run0_8.pickle
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run0_9.pickle
# In generation  1
# Number of estimated functional faults: 155
# Number of reward faults: 0
# Number of non-faults: 1345
#
#
# In generation  2
# Number of estimated functional faults: 193
# Number of reward faults: 0
# Number of non-faults: 1304
#
#
# In generation  3
# Number of estimated functional faults: 271
# Number of reward faults: 0
# Number of non-faults: 1223
#
#
# In generation  4
# Number of estimated functional faults: 320
# Number of reward faults: 0
# Number of non-faults: 1170
#
#
# In generation  5
# Number of estimated functional faults: 348
# Number of reward faults: 0
# Number of non-faults: 1140
#
#
# In generation  6
# Number of estimated functional faults: 370
# Number of reward faults: 0
# Number of non-faults: 1115
#
#
# In generation  7
# Number of estimated functional faults: 415
# Number of reward faults: 0
# Number of non-faults: 1069
#
#
# In generation  8
# Number of estimated functional faults: 449
# Number of reward faults: 0
# Number of non-faults: 1024
#
#
# In generation  9
# Number of estimated functional faults: 465
# Number of reward faults: 0
# Number of non-faults: 1014
#
#
# In generation  10
# Number of estimated functional faults: 515
# Number of reward faults: 0
# Number of non-faults: 971
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run0_9.pickle
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run1_0.pickle
# In generation  1
# Number of estimated functional faults: 169
# Number of reward faults: 0
# Number of non-faults: 1330
#
#
# In generation  2
# Number of estimated functional faults: 224
# Number of reward faults: 0
# Number of non-faults: 1275
#
#
# In generation  3
# Number of estimated functional faults: 273
# Number of reward faults: 0
# Number of non-faults: 1225
#
#
# In generation  4
# Number of estimated functional faults: 288
# Number of reward faults: 0
# Number of non-faults: 1209
#
#
# In generation  5
# Number of estimated functional faults: 328
# Number of reward faults: 0
# Number of non-faults: 1161
#
#
# In generation  6
# Number of estimated functional faults: 378
# Number of reward faults: 0
# Number of non-faults: 1107
#
#
# In generation  7
# Number of estimated functional faults: 410
# Number of reward faults: 0
# Number of non-faults: 1080
#
#
# In generation  8
# Number of estimated functional faults: 415
# Number of reward faults: 0
# Number of non-faults: 1075
#
#
# In generation  9
# Number of estimated functional faults: 415
# Number of reward faults: 0
# Number of non-faults: 1061
#
#
# In generation  10
# Number of estimated functional faults: 477
# Number of reward faults: 0
# Number of non-faults: 996
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run1_0.pickle
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run1_1.pickle
# In generation  1
# Number of estimated functional faults: 126
# Number of reward faults: 0
# Number of non-faults: 1374
#
#
# In generation  2
# Number of estimated functional faults: 150
# Number of reward faults: 0
# Number of non-faults: 1351
#
#
# In generation  3
# Number of estimated functional faults: 210
# Number of reward faults: 0
# Number of non-faults: 1288
#
#
# In generation  4
# Number of estimated functional faults: 269
# Number of reward faults: 0
# Number of non-faults: 1228
#
#
# In generation  5
# Number of estimated functional faults: 314
# Number of reward faults: 0
# Number of non-faults: 1184
#
#
# In generation  6
# Number of estimated functional faults: 343
# Number of reward faults: 0
# Number of non-faults: 1153
#
#
# In generation  7
# Number of estimated functional faults: 417
# Number of reward faults: 0
# Number of non-faults: 1080
#
#
# In generation  8
# Number of estimated functional faults: 479
# Number of reward faults: 0
# Number of non-faults: 1017
#
#
# In generation  9
# Number of estimated functional faults: 515
# Number of reward faults: 0
# Number of non-faults: 984
#
#
# In generation  10
# Number of estimated functional faults: 532
# Number of reward faults: 0
# Number of non-faults: 964
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run1_1.pickle
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run1_2.pickle
# In generation  1
# Number of estimated functional faults: 133
# Number of reward faults: 0
# Number of non-faults: 1368
#
#
# In generation  2
# Number of estimated functional faults: 183
# Number of reward faults: 0
# Number of non-faults: 1317
#
#
# In generation  3
# Number of estimated functional faults: 217
# Number of reward faults: 0
# Number of non-faults: 1283
#
#
# In generation  4
# Number of estimated functional faults: 291
# Number of reward faults: 0
# Number of non-faults: 1208
#
#
# In generation  5
# Number of estimated functional faults: 315
# Number of reward faults: 0
# Number of non-faults: 1185
#
#
# In generation  6
# Number of estimated functional faults: 369
# Number of reward faults: 0
# Number of non-faults: 1128
#
#
# In generation  7
# Number of estimated functional faults: 424
# Number of reward faults: 0
# Number of non-faults: 1068
#
#
# In generation  8
# Number of estimated functional faults: 444
# Number of reward faults: 0
# Number of non-faults: 1046
#
#
# In generation  9
# Number of estimated functional faults: 429
# Number of reward faults: 0
# Number of non-faults: 1058
#
#
# In generation  10
# Number of estimated functional faults: 462
# Number of reward faults: 0
# Number of non-faults: 1017
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run1_2.pickle
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run1_3.pickle
# In generation  1
# Number of estimated functional faults: 144
# Number of reward faults: 0
# Number of non-faults: 1355
#
#
# In generation  2
# Number of estimated functional faults: 206
# Number of reward faults: 0
# Number of non-faults: 1293
#
#
# In generation  3
# Number of estimated functional faults: 303
# Number of reward faults: 0
# Number of non-faults: 1195
#
#
# In generation  4
# Number of estimated functional faults: 300
# Number of reward faults: 0
# Number of non-faults: 1199
#
#
# In generation  5
# Number of estimated functional faults: 354
# Number of reward faults: 0
# Number of non-faults: 1145
#
#
# In generation  6
# Number of estimated functional faults: 416
# Number of reward faults: 0
# Number of non-faults: 1078
#
#
# In generation  7
# Number of estimated functional faults: 428
# Number of reward faults: 0
# Number of non-faults: 1065
#
#
# In generation  8
# Number of estimated functional faults: 506
# Number of reward faults: 0
# Number of non-faults: 988
#
#
# In generation  9
# Number of estimated functional faults: 541
# Number of reward faults: 0
# Number of non-faults: 953
#
#
# In generation  10
# Number of estimated functional faults: 543
# Number of reward faults: 0
# Number of non-faults: 947
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run1_3.pickle
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run1_4.pickle
# In generation  1
# Number of estimated functional faults: 134
# Number of reward faults: 0
# Number of non-faults: 1364
#
#
# In generation  2
# Number of estimated functional faults: 159
# Number of reward faults: 0
# Number of non-faults: 1336
#
#
# In generation  3
# Number of estimated functional faults: 226
# Number of reward faults: 0
# Number of non-faults: 1271
#
#
# In generation  4
# Number of estimated functional faults: 238
# Number of reward faults: 0
# Number of non-faults: 1256
#
#
# In generation  5
# Number of estimated functional faults: 326
# Number of reward faults: 0
# Number of non-faults: 1165
#
#
# In generation  6
# Number of estimated functional faults: 380
# Number of reward faults: 0
# Number of non-faults: 1110
#
#
# In generation  7
# Number of estimated functional faults: 417
# Number of reward faults: 0
# Number of non-faults: 1074
#
#
# In generation  8
# Number of estimated functional faults: 484
# Number of reward faults: 0
# Number of non-faults: 1001
#
#
# In generation  9
# Number of estimated functional faults: 532
# Number of reward faults: 0
# Number of non-faults: 947
#
#
# In generation  10
# Number of estimated functional faults: 506
# Number of reward faults: 0
# Number of non-faults: 985
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run1_4.pickle
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run1_5.pickle
# In generation  1
# Number of estimated functional faults: 120
# Number of reward faults: 0
# Number of non-faults: 1379
#
#
# In generation  2
# Number of estimated functional faults: 185
# Number of reward faults: 0
# Number of non-faults: 1313
#
#
# In generation  3
# Number of estimated functional faults: 210
# Number of reward faults: 0
# Number of non-faults: 1289
#
#
# In generation  4
# Number of estimated functional faults: 234
# Number of reward faults: 0
# Number of non-faults: 1265
#
#
# In generation  5
# Number of estimated functional faults: 311
# Number of reward faults: 0
# Number of non-faults: 1184
#
#
# In generation  6
# Number of estimated functional faults: 342
# Number of reward faults: 0
# Number of non-faults: 1143
#
#
# In generation  7
# Number of estimated functional faults: 429
# Number of reward faults: 0
# Number of non-faults: 1053
#
#
# In generation  8
# Number of estimated functional faults: 484
# Number of reward faults: 0
# Number of non-faults: 1006
#
#
# In generation  9
# Number of estimated functional faults: 537
# Number of reward faults: 0
# Number of non-faults: 952
#
#
# In generation  10
# Number of estimated functional faults: 532
# Number of reward faults: 0
# Number of non-faults: 959
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run1_5.pickle
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run1_6.pickle
# In generation  1
# Number of estimated functional faults: 141
# Number of reward faults: 0
# Number of non-faults: 1356
#
#
# In generation  2
# Number of estimated functional faults: 191
# Number of reward faults: 0
# Number of non-faults: 1308
#
#
# In generation  3
# Number of estimated functional faults: 280
# Number of reward faults: 0
# Number of non-faults: 1214
#
#
# In generation  4
# Number of estimated functional faults: 293
# Number of reward faults: 0
# Number of non-faults: 1200
#
#
# In generation  5
# Number of estimated functional faults: 365
# Number of reward faults: 0
# Number of non-faults: 1122
#
#
# In generation  6
# Number of estimated functional faults: 394
# Number of reward faults: 0
# Number of non-faults: 1094
#
#
# In generation  7
# Number of estimated functional faults: 409
# Number of reward faults: 0
# Number of non-faults: 1069
#
#
# In generation  8
# Number of estimated functional faults: 464
# Number of reward faults: 0
# Number of non-faults: 1011
#
#
# In generation  9
# Number of estimated functional faults: 479
# Number of reward faults: 0
# Number of non-faults: 993
#
#
# In generation  10
# Number of estimated functional faults: 489
# Number of reward faults: 0
# Number of non-faults: 982
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run1_6.pickle
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run1_7.pickle
# In generation  1
# Number of estimated functional faults: 153
# Number of reward faults: 0
# Number of non-faults: 1348
#
#
# In generation  2
# Number of estimated functional faults: 197
# Number of reward faults: 0
# Number of non-faults: 1302
#
#
# In generation  3
# Number of estimated functional faults: 238
# Number of reward faults: 0
# Number of non-faults: 1256
#
#
# In generation  4
# Number of estimated functional faults: 299
# Number of reward faults: 0
# Number of non-faults: 1196
#
#
# In generation  5
# Number of estimated functional faults: 342
# Number of reward faults: 0
# Number of non-faults: 1150
#
#
# In generation  6
# Number of estimated functional faults: 325
# Number of reward faults: 0
# Number of non-faults: 1167
#
#
# In generation  7
# Number of estimated functional faults: 424
# Number of reward faults: 0
# Number of non-faults: 1062
#
#
# In generation  8
# Number of estimated functional faults: 412
# Number of reward faults: 0
# Number of non-faults: 1071
#
#
# In generation  9
# Number of estimated functional faults: 473
# Number of reward faults: 0
# Number of non-faults: 1004
#
#
# In generation  10
# Number of estimated functional faults: 523
# Number of reward faults: 0
# Number of non-faults: 934
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run1_7.pickle
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run1_8.pickle
# In generation  1
# Number of estimated functional faults: 153
# Number of reward faults: 0
# Number of non-faults: 1347
#
#
# In generation  2
# Number of estimated functional faults: 213
# Number of reward faults: 0
# Number of non-faults: 1288
#
#
# In generation  3
# Number of estimated functional faults: 234
# Number of reward faults: 0
# Number of non-faults: 1264
#
#
# In generation  4
# Number of estimated functional faults: 303
# Number of reward faults: 0
# Number of non-faults: 1193
#
#
# In generation  5
# Number of estimated functional faults: 335
# Number of reward faults: 0
# Number of non-faults: 1155
#
#
# In generation  6
# Number of estimated functional faults: 392
# Number of reward faults: 0
# Number of non-faults: 1095
#
#
# In generation  7
# Number of estimated functional faults: 407
# Number of reward faults: 0
# Number of non-faults: 1081
#
#
# In generation  8
# Number of estimated functional faults: 456
# Number of reward faults: 0
# Number of non-faults: 1029
#
#
# In generation  9
# Number of estimated functional faults: 458
# Number of reward faults: 0
# Number of non-faults: 1034
#
#
# In generation  10
# Number of estimated functional faults: 515
# Number of reward faults: 0
# Number of non-faults: 967
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run1_8.pickle
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run1_9.pickle
# In generation  1
# Number of estimated functional faults: 135
# Number of reward faults: 0
# Number of non-faults: 1364
#
#
# In generation  2
# Number of estimated functional faults: 224
# Number of reward faults: 0
# Number of non-faults: 1274
#
#
# In generation  3
# Number of estimated functional faults: 243
# Number of reward faults: 0
# Number of non-faults: 1252
#
#
# In generation  4
# Number of estimated functional faults: 288
# Number of reward faults: 0
# Number of non-faults: 1208
#
#
# In generation  5
# Number of estimated functional faults: 301
# Number of reward faults: 0
# Number of non-faults: 1186
#
#
# In generation  6
# Number of estimated functional faults: 307
# Number of reward faults: 0
# Number of non-faults: 1179
#
#
# In generation  7
# Number of estimated functional faults: 338
# Number of reward faults: 0
# Number of non-faults: 1145
#
#
# In generation  8
# Number of estimated functional faults: 383
# Number of reward faults: 0
# Number of non-faults: 1098
#
#
# In generation  9
# Number of estimated functional faults: 437
# Number of reward faults: 0
# Number of non-faults: 1041
#
#
# In generation  10
# Number of estimated functional faults: 470
# Number of reward faults: 0
# Number of non-faults: 1001
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run1_9.pickle

# %% [markdown]
# # Count newly seen abstract state

# %%
import os
items = os.listdir('c:/Users/Student/Desktop/Data/NewResults1207/Generation/')

Drive_model  ="c:/Users/Student/Desktop/Data/dqn-4-1-6-89946.zip"


mtc = gym.make('MountainCar-v0')
mtc_wrapped = StoreAndTerminateWrapper(mtc)
model = DQN('MlpPolicy',env=mtc_wrapped, verbose=1)
model = model.load(Drive_model)

d=500
Read_from_data = True
if Read_from_data:
    with open(f'c:/Users/Student/Desktop/Data/Abstraction/Abstraction_data_sampled_200_{d}.pickle', 'rb') as file2:
        unique1 = pickle.load(file2)
    print("\nd=",d,'\n abs',len(unique1),'\n abs',len(set(unique1))) # check the numbers to see if we have any duplicated abstract state
    uni1 = np.array(unique1) #array for late use
if not Read_from_data:
  unique1,uni1 = Abstract_classes(test,d,model)


thresholds = [-180, 0.04, 0.50]

unseen_abstract_states=[]
unseen_c_states =[]
T_unseen_abstract_states=[]
T_unseen_c_states =[]
for generations in items[:]:
  unseen_abstract_states_buff=[]
  unseen_c_states_buff =[]
  T_unseen_abstract_states_buff=[]
  T_unseen_c_states_buff =[]
  if generations=='res' or generations=='.ipynb_checkpoints' or generations=='Extra':
    continue
  arch2=[]
  stat=[]
  ft=[]
  print("\n\n-----------------------------------------------------\n\n")
  print(f'c:/Users/Student/Desktop/Data/NewResults1207/Generation/{generations}')
  with open(f'c:/Users/Student/Desktop/Data/NewResults1207/Generation/{generations}', 'rb') as file2:
      data = pickle.load(file2)
  for i in range(len(data)):
    if i == 0:
      initial_pop = data[i]
      continue
    rewardfault = []
    estimated_functional_faults=[] 
    nonfaulty=[]
    # epsilon = 0.05
    for ind_ in data[i]:
      last_state = ind_.get_candidate_values()[-2]
      value_ = ind_.get_candidate_values()
      objectives_ = ind_.get_objective_values()
      if fitness_reward(value_)<thresholds[0]:
        rewardfault.append(ind_)
      if objectives_[2]<thresholds[2]:
        estimated_functional_faults.append(ind_)
      if fitness_reward(value_)>thresholds[0] and not(is_functional_fault_last_state(last_state,ind_.get_candidate_values()[-1])):
        nonfaulty.append(ind_)
      # episode = candid.get_candidate_values()
      # record = np.zeros(len(uni1))
      for state, action in value_:
        ab = abstract_state_general(model,state,d)
        if ab == 'end':
          continue
        if ab not in unique1:
          T_unseen_abstract_states_buff.append(ab)
          T_unseen_c_states_buff.append(state)
    print("In generation ", i )
    print("Number of estimated functional faults:",len(estimated_functional_faults))
    print("Number of reward faults:",len(rewardfault))
    print("Number of non-faults:",len(nonfaulty))
    print("\n")
    Build_Archive(data[i],3,thresholds,arch2,initial_pop)
  estimated_functional_faults_Archive=[] 
  for epis in arch2:
    objectives_ = epis.get_objective_values()
    if objectives_[2]<thresholds[2]:
      estimated_functional_faults_Archive.append(epis)
  for candid in estimated_functional_faults_Archive:
    episode = candid.get_candidate_values()
    # record = np.zeros(len(uni1))
    for state, action in episode:
      ab = abstract_state_general(model,state,d)
      if ab == 'end':
        continue
      if ab not in unique1:
        unseen_abstract_states_buff.append(ab)
        unseen_c_states_buff.append(state)
  unseen_abstract_states.append(unseen_abstract_states_buff)
  unseen_c_states.append(unseen_c_states_buff)
  T_unseen_abstract_states.append(T_unseen_abstract_states_buff)
  T_unseen_c_states.append(T_unseen_c_states_buff)
# Out:
# Loading a model without an environment, this model cannot be trained until it has a valid environment.
#
# d= 500
#  abs 93
#  abs 93
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run0_0.pickle
# In generation  1
# Number of estimated functional faults: 149
# Number of reward faults: 0
# Number of non-faults: 1350
#
#
# In generation  2
# Number of estimated functional faults: 194
# Number of reward faults: 0
# Number of non-faults: 1307
#
#
# In generation  3
# Number of estimated functional faults: 226
# Number of reward faults: 0
# Number of non-faults: 1274
#
#
# In generation  4
# Number of estimated functional faults: 259
# Number of reward faults: 0
# Number of non-faults: 1239
#
#
# In generation  5
# Number of estimated functional faults: 309
# Number of reward faults: 0
# Number of non-faults: 1187
#
#
# In generation  6
# Number of estimated functional faults: 337
# Number of reward faults: 0
# Number of non-faults: 1157
#
#
# In generation  7
# Number of estimated functional faults: 334
# Number of reward faults: 0
# Number of non-faults: 1155
#
#
# In generation  8
# Number of estimated functional faults: 408
# Number of reward faults: 0
# Number of non-faults: 1076
#
#
# In generation  9
# Number of estimated functional faults: 433
# Number of reward faults: 0
# Number of non-faults: 1058
#
#
# In generation  10
# Number of estimated functional faults: 429
# Number of reward faults: 0
# Number of non-faults: 1053
#
#
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run0_1.pickle
# In generation  1
# Number of estimated functional faults: 143
# Number of reward faults: 0
# Number of non-faults: 1358
#
#
# In generation  2
# Number of estimated functional faults: 187
# Number of reward faults: 0
# Number of non-faults: 1314
#
#
# In generation  3
# Number of estimated functional faults: 267
# Number of reward faults: 0
# Number of non-faults: 1232
#
#
# In generation  4
# Number of estimated functional faults: 293
# Number of reward faults: 0
# Number of non-faults: 1208
#
#
# In generation  5
# Number of estimated functional faults: 370
# Number of reward faults: 0
# Number of non-faults: 1130
#
#
# In generation  6
# Number of estimated functional faults: 416
# Number of reward faults: 0
# Number of non-faults: 1080
#
#
# In generation  7
# Number of estimated functional faults: 448
# Number of reward faults: 0
# Number of non-faults: 1045
#
#
# In generation  8
# Number of estimated functional faults: 516
# Number of reward faults: 0
# Number of non-faults: 975
#
#
# In generation  9
# Number of estimated functional faults: 525
# Number of reward faults: 0
# Number of non-faults: 965
#
#
# In generation  10
# Number of estimated functional faults: 567
# Number of reward faults: 0
# Number of non-faults: 920
#
#
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run0_2.pickle
# In generation  1
# Number of estimated functional faults: 140
# Number of reward faults: 0
# Number of non-faults: 1357
#
#
# In generation  2
# Number of estimated functional faults: 171
# Number of reward faults: 0
# Number of non-faults: 1327
#
#
# In generation  3
# Number of estimated functional faults: 215
# Number of reward faults: 0
# Number of non-faults: 1280
#
#
# In generation  4
# Number of estimated functional faults: 244
# Number of reward faults: 0
# Number of non-faults: 1244
#
#
# In generation  5
# Number of estimated functional faults: 324
# Number of reward faults: 0
# Number of non-faults: 1166
#
#
# In generation  6
# Number of estimated functional faults: 348
# Number of reward faults: 0
# Number of non-faults: 1133
#
#
# In generation  7
# Number of estimated functional faults: 378
# Number of reward faults: 0
# Number of non-faults: 1112
#
#
# In generation  8
# Number of estimated functional faults: 401
# Number of reward faults: 0
# Number of non-faults: 1085
#
#
# In generation  9
# Number of estimated functional faults: 453
# Number of reward faults: 0
# Number of non-faults: 1032
#
#
# In generation  10
# Number of estimated functional faults: 515
# Number of reward faults: 0
# Number of non-faults: 967
#
#
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run0_3.pickle
# In generation  1
# Number of estimated functional faults: 159
# Number of reward faults: 0
# Number of non-faults: 1339
#
#
# In generation  2
# Number of estimated functional faults: 204
# Number of reward faults: 0
# Number of non-faults: 1293
#
#
# In generation  3
# Number of estimated functional faults: 270
# Number of reward faults: 0
# Number of non-faults: 1225
#
#
# In generation  4
# Number of estimated functional faults: 319
# Number of reward faults: 0
# Number of non-faults: 1169
#
#
# In generation  5
# Number of estimated functional faults: 331
# Number of reward faults: 0
# Number of non-faults: 1141
#
#
# In generation  6
# Number of estimated functional faults: 376
# Number of reward faults: 0
# Number of non-faults: 1090
#
#
# In generation  7
# Number of estimated functional faults: 431
# Number of reward faults: 0
# Number of non-faults: 1033
#
#
# In generation  8
# Number of estimated functional faults: 435
# Number of reward faults: 0
# Number of non-faults: 1018
#
#
# In generation  9
# Number of estimated functional faults: 508
# Number of reward faults: 0
# Number of non-faults: 955
#
#
# In generation  10
# Number of estimated functional faults: 533
# Number of reward faults: 0
# Number of non-faults: 929
#
#
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run0_4.pickle
# In generation  1
# Number of estimated functional faults: 151
# Number of reward faults: 0
# Number of non-faults: 1348
#
#
# In generation  2
# Number of estimated functional faults: 178
# Number of reward faults: 0
# Number of non-faults: 1323
#
#
# In generation  3
# Number of estimated functional faults: 241
# Number of reward faults: 0
# Number of non-faults: 1260
#
#
# In generation  4
# Number of estimated functional faults: 286
# Number of reward faults: 0
# Number of non-faults: 1215
#
#
# In generation  5
# Number of estimated functional faults: 311
# Number of reward faults: 0
# Number of non-faults: 1188
#
#
# In generation  6
# Number of estimated functional faults: 341
# Number of reward faults: 0
# Number of non-faults: 1155
#
#
# In generation  7
# Number of estimated functional faults: 395
# Number of reward faults: 0
# Number of non-faults: 1094
#
#
# In generation  8
# Number of estimated functional faults: 401
# Number of reward faults: 0
# Number of non-faults: 1078
#
#
# In generation  9
# Number of estimated functional faults: 463
# Number of reward faults: 0
# Number of non-faults: 1013
#
#
# In generation  10
# Number of estimated functional faults: 508
# Number of reward faults: 0
# Number of non-faults: 963
#
#
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run0_5.pickle
# In generation  1
# Number of estimated functional faults: 137
# Number of reward faults: 0
# Number of non-faults: 1363
#
#
# In generation  2
# Number of estimated functional faults: 174
# Number of reward faults: 0
# Number of non-faults: 1327
#
#
# In generation  3
# Number of estimated functional faults: 222
# Number of reward faults: 0
# Number of non-faults: 1275
#
#
# In generation  4
# Number of estimated functional faults: 270
# Number of reward faults: 0
# Number of non-faults: 1229
#
#
# In generation  5
# Number of estimated functional faults: 287
# Number of reward faults: 0
# Number of non-faults: 1208
#
#
# In generation  6
# Number of estimated functional faults: 351
# Number of reward faults: 0
# Number of non-faults: 1142
#
#
# In generation  7
# Number of estimated functional faults: 395
# Number of reward faults: 0
# Number of non-faults: 1096
#
#
# In generation  8
# Number of estimated functional faults: 416
# Number of reward faults: 0
# Number of non-faults: 1069
#
#
# In generation  9
# Number of estimated functional faults: 506
# Number of reward faults: 0
# Number of non-faults: 981
#
#
# In generation  10
# Number of estimated functional faults: 524
# Number of reward faults: 0
# Number of non-faults: 952
#
#
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run0_6.pickle
# In generation  1
# Number of estimated functional faults: 120
# Number of reward faults: 0
# Number of non-faults: 1378
#
#
# In generation  2
# Number of estimated functional faults: 184
# Number of reward faults: 0
# Number of non-faults: 1313
#
#
# In generation  3
# Number of estimated functional faults: 227
# Number of reward faults: 0
# Number of non-faults: 1266
#
#
# In generation  4
# Number of estimated functional faults: 232
# Number of reward faults: 0
# Number of non-faults: 1249
#
#
# In generation  5
# Number of estimated functional faults: 295
# Number of reward faults: 0
# Number of non-faults: 1189
#
#
# In generation  6
# Number of estimated functional faults: 323
# Number of reward faults: 0
# Number of non-faults: 1148
#
#
# In generation  7
# Number of estimated functional faults: 383
# Number of reward faults: 0
# Number of non-faults: 1074
#
#
# In generation  8
# Number of estimated functional faults: 348
# Number of reward faults: 0
# Number of non-faults: 1114
#
#
# In generation  9
# Number of estimated functional faults: 415
# Number of reward faults: 0
# Number of non-faults: 1046
#
#
# In generation  10
# Number of estimated functional faults: 477
# Number of reward faults: 0
# Number of non-faults: 960
#
#
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run0_7.pickle
# In generation  1
# Number of estimated functional faults: 150
# Number of reward faults: 0
# Number of non-faults: 1350
#
#
# In generation  2
# Number of estimated functional faults: 180
# Number of reward faults: 0
# Number of non-faults: 1317
#
#
# In generation  3
# Number of estimated functional faults: 236
# Number of reward faults: 0
# Number of non-faults: 1258
#
#
# In generation  4
# Number of estimated functional faults: 290
# Number of reward faults: 0
# Number of non-faults: 1204
#
#
# In generation  5
# Number of estimated functional faults: 295
# Number of reward faults: 0
# Number of non-faults: 1200
#
#
# In generation  6
# Number of estimated functional faults: 355
# Number of reward faults: 0
# Number of non-faults: 1131
#
#
# In generation  7
# Number of estimated functional faults: 396
# Number of reward faults: 0
# Number of non-faults: 1094
#
#
# In generation  8
# Number of estimated functional faults: 398
# Number of reward faults: 0
# Number of non-faults: 1090
#
#
# In generation  9
# Number of estimated functional faults: 468
# Number of reward faults: 0
# Number of non-faults: 1007
#
#
# In generation  10
# Number of estimated functional faults: 489
# Number of reward faults: 0
# Number of non-faults: 987
#
#
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run0_8.pickle
# In generation  1
# Number of estimated functional faults: 165
# Number of reward faults: 0
# Number of non-faults: 1333
#
#
# In generation  2
# Number of estimated functional faults: 229
# Number of reward faults: 0
# Number of non-faults: 1267
#
#
# In generation  3
# Number of estimated functional faults: 247
# Number of reward faults: 0
# Number of non-faults: 1249
#
#
# In generation  4
# Number of estimated functional faults: 318
# Number of reward faults: 0
# Number of non-faults: 1170
#
#
# In generation  5
# Number of estimated functional faults: 368
# Number of reward faults: 0
# Number of non-faults: 1106
#
#
# In generation  6
# Number of estimated functional faults: 448
# Number of reward faults: 0
# Number of non-faults: 1029
#
#
# In generation  7
# Number of estimated functional faults: 445
# Number of reward faults: 0
# Number of non-faults: 1028
#
#
# In generation  8
# Number of estimated functional faults: 489
# Number of reward faults: 0
# Number of non-faults: 1000
#
#
# In generation  9
# Number of estimated functional faults: 512
# Number of reward faults: 0
# Number of non-faults: 965
#
#
# In generation  10
# Number of estimated functional faults: 504
# Number of reward faults: 0
# Number of non-faults: 962
#
#
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run0_9.pickle
# In generation  1
# Number of estimated functional faults: 155
# Number of reward faults: 0
# Number of non-faults: 1345
#
#
# In generation  2
# Number of estimated functional faults: 193
# Number of reward faults: 0
# Number of non-faults: 1304
#
#
# In generation  3
# Number of estimated functional faults: 271
# Number of reward faults: 0
# Number of non-faults: 1223
#
#
# In generation  4
# Number of estimated functional faults: 320
# Number of reward faults: 0
# Number of non-faults: 1170
#
#
# In generation  5
# Number of estimated functional faults: 348
# Number of reward faults: 0
# Number of non-faults: 1140
#
#
# In generation  6
# Number of estimated functional faults: 370
# Number of reward faults: 0
# Number of non-faults: 1115
#
#
# In generation  7
# Number of estimated functional faults: 415
# Number of reward faults: 0
# Number of non-faults: 1069
#
#
# In generation  8
# Number of estimated functional faults: 449
# Number of reward faults: 0
# Number of non-faults: 1024
#
#
# In generation  9
# Number of estimated functional faults: 465
# Number of reward faults: 0
# Number of non-faults: 1014
#
#
# In generation  10
# Number of estimated functional faults: 515
# Number of reward faults: 0
# Number of non-faults: 971
#
#
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run1_0.pickle
# In generation  1
# Number of estimated functional faults: 169
# Number of reward faults: 0
# Number of non-faults: 1330
#
#
# In generation  2
# Number of estimated functional faults: 224
# Number of reward faults: 0
# Number of non-faults: 1275
#
#
# In generation  3
# Number of estimated functional faults: 273
# Number of reward faults: 0
# Number of non-faults: 1225
#
#
# In generation  4
# Number of estimated functional faults: 288
# Number of reward faults: 0
# Number of non-faults: 1209
#
#
# In generation  5
# Number of estimated functional faults: 328
# Number of reward faults: 0
# Number of non-faults: 1161
#
#
# In generation  6
# Number of estimated functional faults: 378
# Number of reward faults: 0
# Number of non-faults: 1107
#
#
# In generation  7
# Number of estimated functional faults: 410
# Number of reward faults: 0
# Number of non-faults: 1080
#
#
# In generation  8
# Number of estimated functional faults: 415
# Number of reward faults: 0
# Number of non-faults: 1075
#
#
# In generation  9
# Number of estimated functional faults: 415
# Number of reward faults: 0
# Number of non-faults: 1061
#
#
# In generation  10
# Number of estimated functional faults: 477
# Number of reward faults: 0
# Number of non-faults: 996
#
#
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run1_1.pickle
# In generation  1
# Number of estimated functional faults: 126
# Number of reward faults: 0
# Number of non-faults: 1374
#
#
# In generation  2
# Number of estimated functional faults: 150
# Number of reward faults: 0
# Number of non-faults: 1351
#
#
# In generation  3
# Number of estimated functional faults: 210
# Number of reward faults: 0
# Number of non-faults: 1288
#
#
# In generation  4
# Number of estimated functional faults: 269
# Number of reward faults: 0
# Number of non-faults: 1228
#
#
# In generation  5
# Number of estimated functional faults: 314
# Number of reward faults: 0
# Number of non-faults: 1184
#
#
# In generation  6
# Number of estimated functional faults: 343
# Number of reward faults: 0
# Number of non-faults: 1153
#
#
# In generation  7
# Number of estimated functional faults: 417
# Number of reward faults: 0
# Number of non-faults: 1080
#
#
# In generation  8
# Number of estimated functional faults: 479
# Number of reward faults: 0
# Number of non-faults: 1017
#
#
# In generation  9
# Number of estimated functional faults: 515
# Number of reward faults: 0
# Number of non-faults: 984
#
#
# In generation  10
# Number of estimated functional faults: 532
# Number of reward faults: 0
# Number of non-faults: 964
#
#
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run1_2.pickle
# In generation  1
# Number of estimated functional faults: 133
# Number of reward faults: 0
# Number of non-faults: 1368
#
#
# In generation  2
# Number of estimated functional faults: 183
# Number of reward faults: 0
# Number of non-faults: 1317
#
#
# In generation  3
# Number of estimated functional faults: 217
# Number of reward faults: 0
# Number of non-faults: 1283
#
#
# In generation  4
# Number of estimated functional faults: 291
# Number of reward faults: 0
# Number of non-faults: 1208
#
#
# In generation  5
# Number of estimated functional faults: 315
# Number of reward faults: 0
# Number of non-faults: 1185
#
#
# In generation  6
# Number of estimated functional faults: 369
# Number of reward faults: 0
# Number of non-faults: 1128
#
#
# In generation  7
# Number of estimated functional faults: 424
# Number of reward faults: 0
# Number of non-faults: 1068
#
#
# In generation  8
# Number of estimated functional faults: 444
# Number of reward faults: 0
# Number of non-faults: 1046
#
#
# In generation  9
# Number of estimated functional faults: 429
# Number of reward faults: 0
# Number of non-faults: 1058
#
#
# In generation  10
# Number of estimated functional faults: 462
# Number of reward faults: 0
# Number of non-faults: 1017
#
#
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run1_3.pickle
# In generation  1
# Number of estimated functional faults: 144
# Number of reward faults: 0
# Number of non-faults: 1355
#
#
# In generation  2
# Number of estimated functional faults: 206
# Number of reward faults: 0
# Number of non-faults: 1293
#
#
# In generation  3
# Number of estimated functional faults: 303
# Number of reward faults: 0
# Number of non-faults: 1195
#
#
# In generation  4
# Number of estimated functional faults: 300
# Number of reward faults: 0
# Number of non-faults: 1199
#
#
# In generation  5
# Number of estimated functional faults: 354
# Number of reward faults: 0
# Number of non-faults: 1145
#
#
# In generation  6
# Number of estimated functional faults: 416
# Number of reward faults: 0
# Number of non-faults: 1078
#
#
# In generation  7
# Number of estimated functional faults: 428
# Number of reward faults: 0
# Number of non-faults: 1065
#
#
# In generation  8
# Number of estimated functional faults: 506
# Number of reward faults: 0
# Number of non-faults: 988
#
#
# In generation  9
# Number of estimated functional faults: 541
# Number of reward faults: 0
# Number of non-faults: 953
#
#
# In generation  10
# Number of estimated functional faults: 543
# Number of reward faults: 0
# Number of non-faults: 947
#
#
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run1_4.pickle
# In generation  1
# Number of estimated functional faults: 134
# Number of reward faults: 0
# Number of non-faults: 1364
#
#
# In generation  2
# Number of estimated functional faults: 159
# Number of reward faults: 0
# Number of non-faults: 1336
#
#
# In generation  3
# Number of estimated functional faults: 226
# Number of reward faults: 0
# Number of non-faults: 1271
#
#
# In generation  4
# Number of estimated functional faults: 238
# Number of reward faults: 0
# Number of non-faults: 1256
#
#
# In generation  5
# Number of estimated functional faults: 326
# Number of reward faults: 0
# Number of non-faults: 1165
#
#
# In generation  6
# Number of estimated functional faults: 380
# Number of reward faults: 0
# Number of non-faults: 1110
#
#
# In generation  7
# Number of estimated functional faults: 417
# Number of reward faults: 0
# Number of non-faults: 1074
#
#
# In generation  8
# Number of estimated functional faults: 484
# Number of reward faults: 0
# Number of non-faults: 1001
#
#
# In generation  9
# Number of estimated functional faults: 532
# Number of reward faults: 0
# Number of non-faults: 947
#
#
# In generation  10
# Number of estimated functional faults: 506
# Number of reward faults: 0
# Number of non-faults: 985
#
#
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run1_5.pickle
# In generation  1
# Number of estimated functional faults: 120
# Number of reward faults: 0
# Number of non-faults: 1379
#
#
# In generation  2
# Number of estimated functional faults: 185
# Number of reward faults: 0
# Number of non-faults: 1313
#
#
# In generation  3
# Number of estimated functional faults: 210
# Number of reward faults: 0
# Number of non-faults: 1289
#
#
# In generation  4
# Number of estimated functional faults: 234
# Number of reward faults: 0
# Number of non-faults: 1265
#
#
# In generation  5
# Number of estimated functional faults: 311
# Number of reward faults: 0
# Number of non-faults: 1184
#
#
# In generation  6
# Number of estimated functional faults: 342
# Number of reward faults: 0
# Number of non-faults: 1143
#
#
# In generation  7
# Number of estimated functional faults: 429
# Number of reward faults: 0
# Number of non-faults: 1053
#
#
# In generation  8
# Number of estimated functional faults: 484
# Number of reward faults: 0
# Number of non-faults: 1006
#
#
# In generation  9
# Number of estimated functional faults: 537
# Number of reward faults: 0
# Number of non-faults: 952
#
#
# In generation  10
# Number of estimated functional faults: 532
# Number of reward faults: 0
# Number of non-faults: 959
#
#
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run1_6.pickle
# In generation  1
# Number of estimated functional faults: 141
# Number of reward faults: 0
# Number of non-faults: 1356
#
#
# In generation  2
# Number of estimated functional faults: 191
# Number of reward faults: 0
# Number of non-faults: 1308
#
#
# In generation  3
# Number of estimated functional faults: 280
# Number of reward faults: 0
# Number of non-faults: 1214
#
#
# In generation  4
# Number of estimated functional faults: 293
# Number of reward faults: 0
# Number of non-faults: 1200
#
#
# In generation  5
# Number of estimated functional faults: 365
# Number of reward faults: 0
# Number of non-faults: 1122
#
#
# In generation  6
# Number of estimated functional faults: 394
# Number of reward faults: 0
# Number of non-faults: 1094
#
#
# In generation  7
# Number of estimated functional faults: 409
# Number of reward faults: 0
# Number of non-faults: 1069
#
#
# In generation  8
# Number of estimated functional faults: 464
# Number of reward faults: 0
# Number of non-faults: 1011
#
#
# In generation  9
# Number of estimated functional faults: 479
# Number of reward faults: 0
# Number of non-faults: 993
#
#
# In generation  10
# Number of estimated functional faults: 489
# Number of reward faults: 0
# Number of non-faults: 982
#
#
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run1_7.pickle
# In generation  1
# Number of estimated functional faults: 153
# Number of reward faults: 0
# Number of non-faults: 1348
#
#
# In generation  2
# Number of estimated functional faults: 197
# Number of reward faults: 0
# Number of non-faults: 1302
#
#
# In generation  3
# Number of estimated functional faults: 238
# Number of reward faults: 0
# Number of non-faults: 1256
#
#
# In generation  4
# Number of estimated functional faults: 299
# Number of reward faults: 0
# Number of non-faults: 1196
#
#
# In generation  5
# Number of estimated functional faults: 342
# Number of reward faults: 0
# Number of non-faults: 1150
#
#
# In generation  6
# Number of estimated functional faults: 325
# Number of reward faults: 0
# Number of non-faults: 1167
#
#
# In generation  7
# Number of estimated functional faults: 424
# Number of reward faults: 0
# Number of non-faults: 1062
#
#
# In generation  8
# Number of estimated functional faults: 412
# Number of reward faults: 0
# Number of non-faults: 1071
#
#
# In generation  9
# Number of estimated functional faults: 473
# Number of reward faults: 0
# Number of non-faults: 1004
#
#
# In generation  10
# Number of estimated functional faults: 523
# Number of reward faults: 0
# Number of non-faults: 934
#
#
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run1_8.pickle
# In generation  1
# Number of estimated functional faults: 153
# Number of reward faults: 0
# Number of non-faults: 1347
#
#
# In generation  2
# Number of estimated functional faults: 213
# Number of reward faults: 0
# Number of non-faults: 1288
#
#
# In generation  3
# Number of estimated functional faults: 234
# Number of reward faults: 0
# Number of non-faults: 1264
#
#
# In generation  4
# Number of estimated functional faults: 303
# Number of reward faults: 0
# Number of non-faults: 1193
#
#
# In generation  5
# Number of estimated functional faults: 335
# Number of reward faults: 0
# Number of non-faults: 1155
#
#
# In generation  6
# Number of estimated functional faults: 392
# Number of reward faults: 0
# Number of non-faults: 1095
#
#
# In generation  7
# Number of estimated functional faults: 407
# Number of reward faults: 0
# Number of non-faults: 1081
#
#
# In generation  8
# Number of estimated functional faults: 456
# Number of reward faults: 0
# Number of non-faults: 1029
#
#
# In generation  9
# Number of estimated functional faults: 458
# Number of reward faults: 0
# Number of non-faults: 1034
#
#
# In generation  10
# Number of estimated functional faults: 515
# Number of reward faults: 0
# Number of non-faults: 967
#
#
#
#
# -----------------------------------------------------
#
#
# c:/Users/Student/Desktop/Data/NewResults1207/Generation/Dec07_generations_population1000lastfull_run1_9.pickle
# In generation  1
# Number of estimated functional faults: 135
# Number of reward faults: 0
# Number of non-faults: 1364
#
#
# In generation  2
# Number of estimated functional faults: 224
# Number of reward faults: 0
# Number of non-faults: 1274
#
#
# In generation  3
# Number of estimated functional faults: 243
# Number of reward faults: 0
# Number of non-faults: 1252
#
#
# In generation  4
# Number of estimated functional faults: 288
# Number of reward faults: 0
# Number of non-faults: 1208
#
#
# In generation  5
# Number of estimated functional faults: 301
# Number of reward faults: 0
# Number of non-faults: 1186
#
#
# In generation  6
# Number of estimated functional faults: 307
# Number of reward faults: 0
# Number of non-faults: 1179
#
#
# In generation  7
# Number of estimated functional faults: 338
# Number of reward faults: 0
# Number of non-faults: 1145
#
#
# In generation  8
# Number of estimated functional faults: 383
# Number of reward faults: 0
# Number of non-faults: 1098
#
#
# In generation  9
# Number of estimated functional faults: 437
# Number of reward faults: 0
# Number of non-faults: 1041
#
#
# In generation  10
# Number of estimated functional faults: 470
# Number of reward faults: 0
# Number of non-faults: 1001

# %%
with open(f'c:/Users/Student/Desktop/Data/NewResults1207/newly_seen_abs.pickle', 'wb') as file:
    pickle.dump(T_unseen_abstract_states, file)

with open(f'c:/Users/Student/Desktop/Data/NewResults1207/newly_seen_CC.pickle', 'wb') as file:
    pickle.dump(T_unseen_c_states, file)

# %%
a_arr=[]
for i in range(20):
    print(len(set(T_unseen_abstract_states[i])))
    a_arr.append(len(set(T_unseen_abstract_states[i])))
# Out:
# 7
# 8
# 8
# 8
# 8
# 10
# 10
# 7
# 9
# 7
# 10
# 8
# 9
# 6
# 8
# 8
# 6
# 8
# 10
# 9

# %%
unseen_abs_avg=sum(a_arr)/len(a_arr)
# Out:
# 8.2

# %%
print("Average number of unseen abstract states is:",unseen_abs_avg)
# Out:
# Average number of unseen abstract states is: 8.2

# %%
print("Total number of abstract states:",len(unique1))
# Out:
# Total number of abstract states: 93
